# %% [markdown]
# # 07-Scatter Plots-Matplotlib in Python
# ## By Allen Huang

# %% [markdown]
# Matplotlib Marker Styles: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html
#
# Matplotlib Colormaps: https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y, s = 100, c = 'green', marker = 'o', edgecolor = 'black', linewidth = 1, alpha = 0.7)  # s can change the size; c is color

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]


colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
# when we plot 5 and 7, it has a color called 7. 

plt.scatter(x,y, s = 100, c = colors, cmap = 'Greens', edgecolor = 'black', linewidth = 1, alpha = 0.7)

cbar = plt.colorbar() # create a label for color map
cbar.set_label("Satisfaction")

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]


colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
# when we plot 5 and 7, it has a color called 7. 

sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
      538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]

plt.scatter(x,y, s = sizes, c = colors, cmap = 'Blues', edgecolor = 'black', linewidth = 1, alpha = 0.7)

cbar = plt.colorbar()
cbar.set_label("Satisfaction")

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv('data4.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

plt.scatter(view_count,likes, edgecolor = 'black', linewidth = 1, alpha = 0.7)

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv('data4.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']


plt.scatter(view_count,likes, c = ratio, cmap = 'summer', edgecolor = 'black', linewidth = 1, alpha = 0.7)
plt.xscale('log') # using a log scale to see 
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

cbar = plt.colorbar()
cbar.set_label("Like/dislike ratio")

plt.tight_layout()

plt.show()
