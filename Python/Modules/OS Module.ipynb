# %% [markdown]
# # OS Module in Python
# ## By Allen Huang

# %% [markdown]
# The OS module allows us to interact with the underlying operating system in several different ways.
#
# - Navigate the file system
# - Get file information
# - Look up and change the environment variables
# - Move files around
# - Many more

# %%
# To begin, import the os module. This is a built in module, no third party modules need to be installed.
import os

# %%
# all the attributes and methods that we have access of this module
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_TRAPPED', 'DirEntry', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'MutableMapping', 'NGROUPS_MAX', 'O_ACCMODE', 'O_APPEND', 'O_ASYNC', 'O_CLOEXEC', 'O_CREAT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_EXLOCK', 'O_NDELAY', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O_RDONLY', 'O_RDWR', 'O_SHLOCK', 'O_SYNC', 'O_TRUNC', 'O_WRONLY', 'PRIO_PGRP', 'PRIO_PROCESS', 'PRIO_USER', 'P_ALL', 'P_NOWAIT', 'P_NOWAITO', 'P_PGID', 'P_PID', 'P_WAIT', 'PathLike', 'RTLD_GLOBAL', 'RTLD_LAZY', 'RTLD_LOCAL', 'RTLD_NODELETE', 'RTLD_NOLOAD', 'RTLD_NOW', 'R_OK', 'SCHED_FIFO', 'SCHED_OTHER', 'SCHED_RR', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'ST_NOSUID', 'ST_RDONLY', 'TMP_MAX', 'WCONTINUED', 'WCOREDUMP', 'WEXITED', 'WEXITSTATUS', 'WIFCONTINUED', 'WIFEXITED', 'WIFSIGNALED', 'WIFSTOPPED', 'WNOHANG', 'WNOWAIT', 'WSTOPPED', 'WSTOPSIG', 'WTERMSIG', 'WUNTRACED', 'W_OK', 'X_OK', '_Environ', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_execvpe', '_exists', '_exit', '_fspath', '_fwalk', '_get_exports_list', '_putenv', '_spawnvef', '_unsetenv', '_wrap_close', 'abc', 'abort', 'access', 'altsep', 'chdir', 'chflags', 'chmod', 'chown', 'chroot', 'close', 'closerange', 'confstr', 'confstr_names', 'cpu_count', 'ctermid', 'curdir', 'defpath', 'device_encoding', 'devnull', 'dup', 'dup2', 'environ', 'environb', 'error', 'execl', 'execle', 'execlp', 'execlpe', 'execv', 'execve', 'execvp', 'execvpe', 'extsep', 'fchdir', 'fchmod', 'fchown', 'fdopen', 'fork', 'forkpty', 'fpathconf', 'fsdecode', 'fsencode', 'fspath', 'fstat', 'fstatvfs', 'fsync', 'ftruncate', 'fwalk', 'get_blocking', 'get_exec_path', 'get_inheritable', 'get_terminal_size', 'getcwd', 'getcwdb', 'getegid', 'getenv', 'getenvb', 'geteuid', 'getgid', 'getgrouplist', 'getgroups', 'getloadavg', 'getlogin', 'getpgid', 'getpgrp', 'getpid', 'getppid', 'getpriority', 'getsid', 'getuid', 'initgroups', 'isatty', 'kill', 'killpg', 'lchflags', 'lchmod', 'lchown', 'linesep', 'link', 'listdir', 'lockf', 'lseek', 'lstat', 'major', 'makedev', 'makedirs', 'minor', 'mkdir', 'mkfifo', 'mknod', 'name', 'nice', 'open', 'openpty', 'pardir', 'path', 'pathconf', 'pathconf_names', 'pathsep', 'pipe', 'popen', 'pread', 'putenv', 'pwrite', 'read', 'readlink', 'readv', 'register_at_fork', 'remove', 'removedirs', 'rename', 'renames', 'replace', 'rmdir', 'scandir', 'sched_get_priority_max', 'sched_get_priority_min', 'sched_yield', 'sendfile', 'sep', 'set_blocking', 'set_inheritable', 'setegid', 'seteuid', 'setgid', 'setgroups', 'setpgid', 'setpgrp', 'setpriority', 'setregid', 'setreuid', 'setsid', 'setuid', 'spawnl', 'spawnle', 'spawnlp', 'spawnlpe', 'spawnv', 'spawnve', 'spawnvp', 'spawnvpe', 'st', 'stat', 'stat_result', 'statvfs', 'statvfs_result', 'strerror', 'supports_bytes_environ', 'supports_dir_fd', 'supports_effective_ids', 'supports_fd', 'supports_follow_symlinks', 'symlink', 'sync', 'sys', 'sysconf', 'sysconf_names', 'system', 'tcgetpgrp', 'tcsetpgrp', 'terminal_size', 'times', 'times_result', 'truncate', 'ttyname', 'umask', 'uname', 'uname_result', 'unlink', 'unsetenv', 'urandom', 'utime', 'wait', 'wait3', 'wait4', 'waitpid', 'walk', 'write', 'writev']

# %%
# Get current working directory
os.getcwd()
# Out:
# '/Users/hkmac/Desktop/Carzy Allen Github/Python/Modules'

# %%
# Change directory, this requires a path to change to
os.chdir('/Users/hkmac/Desktop')

# %%
# Get current working directory again
os.getcwd()
# Out:
# '/Users/hkmac/Desktop'

# %%
# List directory, you can pass a path, but by default it is in the current directory
print(os.listdir())
# Out:
# ['~$0105090023—黄子朔—基于数据挖掘的2型糖尿病风险预测与健康管理研究.docx', 'Learning Route.mindnode', 'ML_AndrewNg', '._数据可视化之美中文版.pdf', '数据分析', 'MoreCupsofCoffee.pdf', '.DS_Store', 'Carzy Allen Github', 'Sample - Superstore.xls', '数理统计', 'Electric_Production.csv', '._数据可视化之美中文版.pdf.bdc-downloaded', 'Python', '.localized', '$RECYCLE.BIN', 'UF课程', '~$verletter_Zishuo_Huang.docx', 'Time Series Analysis of Electric Production.html', '~$填空技巧.xlsx', '大学课程', '~$大学西校区电动车棚建设.docx', '李航《统计学习方法》发布算法推导视频啦！（附作业讲解）.webloc', '~$子朔毕业论文.docx', '~$hope to learn XX in workshop.docx', '杂七杂八', '~$say uci修改.docx', '~$阅读 28分.docx', '研究生', 'airpassengers.xlsx', '~$HW3 of Section 2440 - Group 5.xlsx', '~$子朔中期报告.doc', 'iris.data', 'Friends.pdf', '~$时间表.xlsx', '常用书籍', '留学申请', 'Exam1', '~$题目.docx', 'OOP.html', 'function_octave.m', 'SQL Course Materials', 'desktop.ini', '工作', '~$GRE生词本.xlsx', 'Data Analysis using Pandas.html', '~$黄子朔毕业论文.docx', '~$SHUO HUANG.docx']

# %%
# Multiple options for creating directories
# Use for making one directory
os.mkdir('adirfile')  
# Use if you want to create multiple directories at once
os.makedirs('adirsfile/Sub-dir')

# %%
# Remove directories
# Recommended use case
os.rmdir('adirfile')
# Removes intermediate directories if specified
os.removedirs('adirsfile/Sub-dir')

# %%
# Rename a file or folder
# This renames '各种各样'to 杂七杂八'
os.rename('各种各样', '杂七杂八')

# %%
#Look at info about files
print(os.stat('杂七杂八'))
# Useful stat results: st_size (bytes), st_mtime (time stamp)(last modification time)
print(os.stat('杂七杂八').st_size)
print(os.stat('杂七杂八'). st_mtime)
# Out:
# os.stat_result(st_mode=16877, st_ino=1707093, st_dev=16777220, st_nlink=16, st_uid=501, st_gid=20, st_size=512, st_atime=1572713871, st_mtime=1572713870, st_ctime=1572838089)
# 512
# 1572713870.6310544

# %%
from datetime import datetime 
mod_time = os.stat('杂七杂八'). st_mtime
print(datetime.fromtimestamp(mod_time))
# Out:
# 2019-11-02 12:57:50.631054

# %%
# To see entire directory tree and files within
# os.walk is a generator that yields a tuple of 3 values as it walks the directory tree
for dirpath, dirnames, filenames in os.walk('/Users/hkmac/Desktop'): 
    print('Current Path:', dirpath)
    print('Directories:', dirnames)
    print('Files:', filenames)
    print()
# Out:
# Current Path: /Users/hkmac/Desktop
# Directories: ['Learning Route.mindnode', 'ML_AndrewNg', '数据分析', 'Carzy Allen Github', '数理统计', 'Python', '$RECYCLE.BIN', 'UF课程', '大学课程', '杂七杂八', '研究生', '常用书籍', '留学申请', 'Exam1', 'SQL Course Materials', '工作']
# Files: ['~$0105090023—黄子朔—基于数据挖掘的2型糖尿病风险预测与健康管理研究.docx', '._数据可视化之美中文版.pdf', 'MoreCupsofCoffee.pdf', '.DS_Store', 'Sample - Superstore.xls', 'Electric_Production.csv', '._数据可视化之美中文版.pdf.bdc-downloaded', '.localized', '~$verletter_Zishuo_Huang.docx', 'Time Series Analysis of Electric Production.html', '~$填空技巧.xlsx', '~$大学西校区电动车棚建设.docx', '李航《统计学习方法》发布算法推导视频啦！（附作业讲解）.webloc', '~$子朔毕业论文.docx', '~$hope to learn XX in workshop.docx', '~$say uci修改.docx', '~$阅读 28分.docx', 'airpassengers.xlsx', '~$HW3 of Section 2440 - Group 5.xlsx', '~$子朔中期报告.doc', 'iris.data', 'Friends.pdf', '~$时间表.xlsx', '~$题目.docx', 'OOP.html', 'function_octave.m', 'desktop.ini', '~$GRE生词本.xlsx', 'Data Analysis using Pandas.html', '~$黄子朔毕业论文.docx', '~$SHUO HUANG.docx']
#
# Current Path: /Users/hkmac/Desktop/Learning Route.mindnode
# Directories: ['QuickLook', 'resources', 'style.mindnodestyle']
# Files: ['contents.xml', 'viewState.plist']
#
# Current Path: /Users/hkmac/Desktop/Learning Route.mindnode/QuickLook
# Directories: []
# Files: ['Preview.jpg']
#
# Current Path: /Users/hkmac/Desktop/Learning Route.mindnode/resources
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Learning Route.mindnode/style.mindnodestyle
# Directories: []
# Files: ['contents.xml', 'metadata.plist']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg
# Directories: ['Coursera-ML-AndrewNg-Notes', 'ppt', 'machine-learning-ex1']
# Files: ['机器学习个人笔记完整版v5.4-A4打印版.pdf', '.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes
# Directories: ['images', 'markdown', 'code', 'srt', 'html', 'ppt', '.git', 'docx']
# Files: ['机器学习个人笔记完整版v5.4-A4打印版.pdf', '.DS_Store', 'README.md']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/images
# Directories: []
# Files: ['a77886a6eff0f20f9d909975bb69a7ab.png', '6168b654649a0537c67df6f2454dc9ba.png', '789d90327121d3391735087b9276db2a.png', '7f11aa788b1b75c5a534d030b3ebc624.png', 'acdb3ac44f1fe61ff3b5a77d5a4895a1.jpg', '1b37f81896a59145576ae996c9dd4d16.png', '58d098bbb415f2c3797a63bd870c3b8f.png', 'f71fb6102e1ceb616314499a027336dc.jpg', 'b4b43ee98bff9f5e73d841af1fa316bf.png', '44c68412e65e62686a96ad16f278571f.png', '3cc61c6e5fe85c2a7bf8170f5bbfd8c3.png', 'dd33179ceccbd8b0b59a5ae698847049.png', '598db991a7c930c9021cec5f6ab9beb9.png', '22a9a9536d4db17b6d64603fb54dce9e.png', '743a769317d584a66509fc394b4e6095.png', 'c5cd6fa2eb9aea9c581b2d78f2f4ea57.png', '9c769fd59c8a9c9f92200f538d1ab29c.png', 'e01d6da07890e32d46d0616741a3fe64.png', '591785837c95bca369021efa14a8bb1c.png', '2e17f58ce9a79525089a1c2e0b4c0ccc.png', 'fcb35433507a56631dde2b4e543743ee.png', 'a36506049248948c82e598c8c254dc31.png', 'f49730be98810b869951bbe38b6319ba.png', 'eb69baa91c2fc6e7dd8ebdf6c79a6a6f.png', 'd1d551d0c540449d457e312a34434355.png', '743c1d46d4288f8884f0981d437a15c1.png', '3dbee365617e9264831400e4de247adc.png', '2cdc09b8bf67e546df7284ba74601c66.png', 'e7f9a746894c4c7dfd10cfcd9c84b5f9.png', '4f80108ebbb6707d39b7a6da4d2a7a4e.png', '0918b38594709705723ed34bb74928ba.png', '0a930f2083bbeb85837f018b74fd0a02.jpg', 'e2c2dcc31f19ac255566fa616799d496.png', '42a92e07b32b593bb826f8f6bc4d9eb3.png', '171031235527.png', 'dd4a022b5544d50f503c077b3a5a5251.png', 'be39b497588499d671942cc15026e4a2.jpg', 'ac9ad10f115d2d1cd15a0514c8ceeafa.png', '171031235719.png', 'e02eec3ca4688ff1cb9126c8eb13bfed.png', 'c1db5363de0286d223444d6a9225a393.png', 'f4585239738f2b5149608879fa166889.png', 'b72863ce7f85cd491e5b940924ef5a5f.png', 'b8167ff0926046e112acf789dba98057.png', '0a8b49da1ab852f2996a02afcaca2322.png', '38c956acb3bedf4362f40e6c5e8a692f.png', '8293711e1d23414d0a03f6878f5a2d91.jpg', 'bf65f3f3098025530a3c442eea562f8c.jpg', '54d7903564b4416305b26f6ff2e13c04.png', '3ac5e06e852ad3deef4cba782ebe425b.jpg', 'd385f8a293b254454746adee51a027d4.png', '5ec35206e8ae22668d4b4a3c3ea7b292.jpg', '4510b8fbc90ba2b233bb6996529f2df1.png', 'bc48a4b0c7257591643eb50f2bf46db6.jpg', '973216c7b01c910cfa1454da936391c6.png', 'cc66af7cbd88183efc07c8ddf09cbc73.png', '809187c1815e1ec67184699076de51f2.png', '247f96f4e7ab7a259ac9ef1eebe0b503.png', 'f13993f4784d01e7da769b4ec2545cd7.png', 'a47ec797d8a9c331e02ed90bca48a24b.png', '0c93b5efd5fd5601ed475d2c8a0e6dcd.png', 'b8fbe2f6ac48897cf40497a2d034c691.png', 'dfcd1d37526824726d85a655f8951249.png', '0a03d239f2f1d1af057d492bcce276f4.png', 'd4d2c3edbdd8915f4e9d254d2a47d9c7.png', '048f3cac1c32e3dc56160849c4dd60b0.png', 'b2069e4b3e12618f5405500d058118d7.png', '279cfbda6b4d9a2ced1332f086db4d9e.png', '10c06cc39058da2c5eef696d75e65a2c.png', 'd027a0612664ea460247c8637b25e306.jpg', '890f6ea8f857f22002f98c20d52b3bb8.png', '4514b422525aaac1e99add67e44882ee.png', '3d8959d0d12fe9914dc827d5a074b564.jpg', '6bdaff07783e37fcbb1f8765ca06b01b.png', '9fa04927c2bd15780f92a7fafb539179.png', 'ff1db77ec2e83b592bbe1c4153586120.jpg', '08d11f870c5b30536f1965507fa7e7dc.png', 'bd074e119a52163691cff93c3f42a1ee.png', 'fe6dd7acf1a1eddcd09da362ecdf976f.jpg', '4b67374499c0d38ed8670ba74ff892d0.png', 'bca6906add60245bbc24d71e22f8b836.png', '5778e97c411b23487881a87cfca781bb.png', '29df906704d254f18e92a63173dd51e7.jpg', 'f406bc738e5e032be79e52b6facfa48e.png', 'ebd7e196e272737f497853ba60743c44.png', '846b48ec79c9fcee05b20767dcc89558.png', 'f8507899953ed2de68e6b2b83554f9ea.png', 'bdf069136b4b661dd14158496d1d1419.png', '7cf1cd9c123a72ca4137ca515871689d.png', '2c95b316a3c61cf076ef132d3d50b51c.png', 'f4b6dee99cfb4352b3cac5287002e8de.png', 'f86eacc2a74159c068e82ea267a752f7.png', 'dd6239efad3d3ee7a89a28574d7795b3.png', '881986ec5af9d86b6b14b260fb3b3618.png', '59541ab1fda4f92d6f1b508c8e29ab1c.png', '912cb43058cee46ddf51598b7538968c.png', '2d32a23ab895a8e765caf90a7679817e.png', '29c12ee079c079c6408ee032870b2683.jpg', '685180bf1774f7edd2b0856a8aae3498.png', 'ff180f091e9bad9ac185248721437526.png', 'c2233cd74605a9f8fe69fd59547d385 ...
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/markdown
# Directories: []
# Files: ['SUMMARY.md', 'week5.md', 'week1.md', 'math.md', 'week4.md', 'week3.md', 'README.md', 'week7.md', 'week6.md', 'week10.md', 'week2.md', 'week9.md', 'week8.md']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code
# Directories: ['ex4-NN back propagation', 'ex5-bias vs variance', 'ex2-logistic regression', 'img', 'ex3-neural network', 'ex6-SVM', 'ex8-anomaly detection and recommendation', 'ex7-kmeans and PCA', 'ex1-linear regression']
# Files: ['.Rhistory', '.DS_Store', 'README.md', 'Programming Exercise(代码作业).pdf']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex4-NN back propagation
# Directories: []
# Files: ['1- NN back propagation.ipynb', 'ex4data1.mat', 'ex4.pdf', 'ML-Exercise4.ipynb', 'ex4weights.mat']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex5-bias vs variance
# Directories: []
# Files: ['ex5data1.mat', 'ex5.pdf', 'ML-Exercise5.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex2-logistic regression
# Directories: []
# Files: ['ex2data2.txt', 'ex2data1.txt', 'ex2.pdf', '1. logistic_regression_v1.ipynb', 'ML-Exercise2.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/img
# Directories: []
# Files: ['linear_cost.png', 'rcmd_cost.png', 'cov_mat.png', 'logistic_gradient.png', 'reg_cost.png', 'reg_gradient.png', 'nn_regcost.png', 'rcmd_vectorized_grad.png', 'mapped_feature.png', 'logistic_cost.png', 'nn_reg_grad.png', 'rcmd_reg_grad.png', 'gradient_checking.png', 'nn_cost.png', 'linear_reg_cost.png', 'nn_model.png', 'linear_reg_gradient.png', 'rcmd_gradient.png', 'f1_score.png', 'pca_projection.png', 'linear_gradient.png']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex3-neural network
# Directories: []
# Files: ['ex3data1.mat', '向量化标签.png', 'ex3weights.mat', 'ex3.pdf', 'ML-Exercise3.ipynb', '1- neural network.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex6-SVM
# Directories: ['data']
# Files: ['1- linear SVM.ipynb', '2- Gaussian kernels.ipynb', '3- search for the best parameters.ipynb', 'ex6.pdf', '4- spam filter.ipynb', 'ML-Exercise6.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex6-SVM/data
# Directories: []
# Files: ['spamSample1.txt', 'emailSample2.txt', 'spamSample2.txt', 'emailSample1.txt', 'ex6data1.mat', 'ex6data3.mat', 'spamTrain.mat', 'ex6data2.mat', 'vocab.txt', 'spamTest.mat']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex8-anomaly detection and recommendation
# Directories: ['data']
# Files: ['ML-Exercise8.ipynb', 'ex8.pdf', '1- Anomaly detection.ipynb', '2- Recommender system.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex8-anomaly detection and recommendation/data
# Directories: []
# Files: ['ex8data1.mat', 'ex8_movies.mat', 'ex8data2.mat', 'ex8_movieParams.mat', 'movie_ids.txt']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex7-kmeans and PCA
# Directories: ['data']
# Files: ['2- 2D kmeans.ipynb', '4- 2D PCA.ipynb', '1- visualize data.ipynb', 'ML-Exercise7.ipynb', '3- kmeans for image compression.ipynb', 'ex7.pdf', '5- PCA on face data.ipynb']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex7-kmeans and PCA/data
# Directories: []
# Files: ['ex7data1.mat', 'ex7faces.mat', 'ex7data2.mat', 'bird_small.png', 'bird_small.mat']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/code/ex1-linear regression
# Directories: []
# Files: ['1.linear_regreesion_v1.ipynb', 'ML-Exercise1.ipynb', 'ex1.pdf', 'ex1data1.txt', 'ex1data2.txt']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/srt
# Directories: []
# Files: ['中英文字幕srt.zip', 'README.md', '纯英文字幕srt.zip']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/html
# Directories: []
# Files: ['week6.html', 'index.html', 'week7.html', 'week10.html', 'week1.html', 'week2.html', 'week3.html', 'week8.html', 'week4.html', 'week5.html', 'week9.html']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/ppt
# Directories: []
# Files: ['Lecture15.pptx', 'Lecture2.pptx', 'Lecture18.pptx', 'Lecture3.pptx', 'Lecture14.pptx', 'Lecture4.pptx', 'Lecture8.pptx', 'Lecture13.pptx', 'Lecture12.pptx', 'Lecture9.pptx', 'Lecture5.pptx', 'README.md', 'Lecture6.pptx', 'Lecture11.pptx', 'Lecture10.pptx', 'Lecture7.pptx', 'Lecture17.pptx', 'Lecture1.pptx', 'Lecture16.pptx']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs', 'branches']
# Files: ['config', 'HEAD', 'description', 'index', 'packed-refs', 'FETCH_HEAD']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/objects
# Directories: ['pack', 'info']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/objects/pack
# Directories: []
# Files: ['pack-653c4b75b3ddf536b98f061fd1898aa9dc52a0eb.pack', 'pack-653c4b75b3ddf536b98f061fd1898aa9dc52a0eb.idx']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/objects/info
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/info
# Directories: []
# Files: ['exclude']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/logs
# Directories: ['refs']
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/logs/refs
# Directories: ['heads', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/logs/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/logs/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/logs/refs/remotes/origin
# Directories: []
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/hooks
# Directories: []
# Files: ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/refs
# Directories: ['heads', 'tags', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/refs/tags
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/refs/remotes/origin
# Directories: []
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/.git/branches
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/Coursera-ML-AndrewNg-Notes/docx
# Directories: []
# Files: ['机器学习的数学基础.docx', '机器学习个人笔记完整版v5.4.docx', 'README.md']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/ppt
# Directories: []
# Files: ['Week1 part3.pdf', 'Week1 part2.pdf', 'Week1.pdf']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/machine-learning-ex1
# Directories: ['ex1']
# Files: ['.DS_Store', 'ex1.pdf']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/machine-learning-ex1/ex1
# Directories: ['lib']
# Files: ['ex1.m', 'computeCostMulti.m', 'computeCost.m', 'warmUpExercise.m', 'gradientDescentMulti.m', '.DS_Store', 'featureNormalize.m', 'plotData.m', 'token.mat', 'normalEqn.m', 'submit.m', 'ex1data1.txt', 'gradientDescent.m', 'ex1data2.txt', 'ex1_multi.m']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/machine-learning-ex1/ex1/lib
# Directories: ['jsonlab']
# Files: ['submitWithConfiguration.m', 'makeValidFieldName.m']
#
# Current Path: /Users/hkmac/Desktop/ML_AndrewNg/machine-learning-ex1/ex1/lib/jsonlab
# Directories: []
# Files: ['saveubjson.m', 'varargin2struct.m', 'jsonopt.m', 'mergestruct.m', 'loadjson.m', 'LICENSE_BSD.txt', 'ChangeLog.txt', 'README.txt', 'savejson.m', 'AUTHORS.txt', 'loadubjson.m']
#
# Current Path: /Users/hkmac/Desktop/数据分析
# Directories: ['Python', 'ML-From-Scratch', 'Machine Learning A-Z', 'AI知识框架.mindnode', 'Data Science.mindnode', 'SQL']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Python
# Directories: ['书籍', '糖尿病', '语法训练']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Python/书籍
# Directories: []
# Files: ['PYTHON自然语言处理【中文版】 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', '.DS_Store', '深入浅出：使用Python编程 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'python核心编程中文版（第二版） 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', '数据挖掘导论(完整版).Introduction.To.Data.Min.pdf', 'Python语言入门.pdf', '《Python标准库》中文版.pdf']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Python/糖尿病
# Directories: []
# Files: ['dataOrigin.xls', '汇总表 (1).xls', '.DS_Store', '数据预处理 (1).xlsx', 'dataOrigin (1).xls', '清洗后 全部数值wine (1).xls', '清洗后 全部数值wine.xls', '原始健康体检 (1).xls', '原始糖尿病人最新 (1).xls', '原始糖尿病人最新.xls', '原始健康体检.xls', '数据预处理.xlsx']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Python/语法训练
# Directories: []
# Files: ['hello.py', '列表添加.py', 'continue.py', '字典嵌套.py', 'input.py', '我和可爱的小程序.py']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch
# Directories: ['utils', '.ipynb_checkpoints', '.git']
# Files: ['线性判别分析LDA.ipynb', '对数几率回归.ipynb', '.DS_Store', 'HMM_forward.py', 'MCMC-Metropolis-Hastings.py', 'Linear Regression.ipynb', 'Naive Bayes.ipynb', 'KNN.ipynb', 'SVM SMO.ipynb', 'Decision Tree for Classification And Regression.ipynb', 'GaussianMixtureModel.ipynb', 'PageRank.ipynb', 'README.md', 'Xgboost 算法.ipynb', 'TempLinkoping2016.txt', 'GBDT 梯度提升.ipynb', 'PCA.ipynb', 'K-means算法.ipynb', 'LSTM_FS.ipynb', 'Viterbi.py']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/utils
# Directories: ['__pycache__', '.ipynb_checkpoints']
# Files: ['activations.py', '__init__.py', 'Simple RNN.ipynb', 'optimizers.py', 'metric.py', 'MLP.ipynb', 'neural_networks.py', 'losses.py', 'progress.py', 'layers.py']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/utils/__pycache__
# Directories: []
# Files: ['losses.cpython-36.pyc', 'optimizers.cpython-36.pyc', 'progress.cpython-36.pyc', 'activations.cpython-36.pyc', 'layers.cpython-36.pyc', 'neural_networks.cpython-36.pyc', 'metric.cpython-36.pyc', '__init__.cpython-36.pyc']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/utils/.ipynb_checkpoints
# Directories: []
# Files: ['MLP-checkpoint.ipynb', 'Simple RNN-checkpoint.ipynb']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.ipynb_checkpoints
# Directories: []
# Files: ['Linear Regression-checkpoint.ipynb']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs', 'branches']
# Files: ['config', 'HEAD', 'description', 'index', 'packed-refs', 'FETCH_HEAD']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/objects
# Directories: ['pack', 'info']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/objects/pack
# Directories: []
# Files: ['pack-55d34336200ab5e6f565eea85ad5b5b1bf3cbd8a.idx', 'pack-55d34336200ab5e6f565eea85ad5b5b1bf3cbd8a.pack']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/objects/info
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/info
# Directories: []
# Files: ['exclude']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/logs
# Directories: ['refs']
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/logs/refs
# Directories: ['heads', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/logs/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/logs/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/logs/refs/remotes/origin
# Directories: []
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/hooks
# Directories: []
# Files: ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/refs
# Directories: ['heads', 'tags', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/refs/tags
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/refs/remotes/origin
# Directories: []
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/数据分析/ML-From-Scratch/.git/branches
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z
# Directories: ['Part 4 - Clustering', 'Part 3 - Classification', 'Part 9 - Dimensionality Reduction', 'Part 5 - Association Rule Learning', 'Part 7 - Natural Language Processing', 'Part 0 - Welcome to Machine Learning A-Z', 'Part 1 - Data Preprocessing', 'Part 10 - Model Selection & Boosting', 'Part 8 - Deep Learning', 'Part 2 - Regression', 'Part 6 - Reinforcement Learning']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 4 - Clustering
# Directories: ['Section 18 -------------------- Part 4 - Clustering --------------------', 'Section 19 - K-Means Clustering', 'Section 20 - Part Recap']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 4 - Clustering/Section 18 -------------------- Part 4 - Clustering --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 4 - Clustering/Section 19 - K-Means Clustering
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 4 - Clustering/Section 20 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification
# Directories: ['Section 11 - Support Vector Machine (SVM)', 'Section 9 -------------------- Part 3 - Classification --------------------', 'Section 13 - Naive Bayes', 'Section 14 - Decision Tree Classification', 'Section 16 - Evaluating Classification Models Performance', 'Section 17 - Part Recap', 'Section 15 - Random Forest Classification', 'Section 12 - Kernel SVM', 'Section 10 - Logistic Regression']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 11 - Support Vector Machine (SVM)
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 9 -------------------- Part 3 - Classification --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 13 - Naive Bayes
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 14 - Decision Tree Classification
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 16 - Evaluating Classification Models Performance
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 17 - Part Recap
# Directories: []
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 15 - Random Forest Classification
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 12 - Kernel SVM
# Directories: []
# Files: ['.Rhistory', '.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 3 - Classification/Section 10 - Logistic Regression
# Directories: []
# Files: ['.Rhistory', '.DS_Store', '.RData']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 9 - Dimensionality Reduction
# Directories: ['Section 36 - Principal Component Analysis (PCA)', 'Section 37 - Kernel PCA', 'Section 38 - Part Recap', 'Section 35 -------------------- Part 9 - Dimensionality Reduction --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 9 - Dimensionality Reduction/Section 36 - Principal Component Analysis (PCA)
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 9 - Dimensionality Reduction/Section 37 - Kernel PCA
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 9 - Dimensionality Reduction/Section 38 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 9 - Dimensionality Reduction/Section 35 -------------------- Part 9 - Dimensionality Reduction --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 5 - Association Rule Learning
# Directories: ['Section 22 - Apriori', 'Section 23 - Part Recap', 'Section 21 -------------------- Part 5 - Association Rule Learning --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 5 - Association Rule Learning/Section 22 - Apriori
# Directories: []
# Files: ['.Rhistory', '.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 5 - Association Rule Learning/Section 23 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 5 - Association Rule Learning/Section 21 -------------------- Part 5 - Association Rule Learning --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 7 - Natural Language Processing
# Directories: ['Section 30 - Part Recap', 'Section 29 - Natural Language Processing', 'Section 28 -------------------- Part 7 - Natural Language Processing --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 7 - Natural Language Processing/Section 30 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 7 - Natural Language Processing/Section 29 - Natural Language Processing
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 7 - Natural Language Processing/Section 28 -------------------- Part 7 - Natural Language Processing --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 0 - Welcome to Machine Learning A-Z
# Directories: ['Section 1 - Welcome to Machine Learning A-Z !']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 0 - Welcome to Machine Learning A-Z/Section 1 - Welcome to Machine Learning A-Z !
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 1 - Data Preprocessing
# Directories: ['Section 2 -------------------- Part 1 - Data Preprocessing --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------
# Directories: ['Data_Preprocessing']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------/Data_Preprocessing
# Directories: []
# Files: ['data_preprocessing_template.R', '.Rhistory', '.DS_Store', 'categorical_data.py', 'Data_Preprocessing_R My.R', 'data_preprocessing_template.py', 'Data.csv', 'missing_data.R', '.RData', 'missing_data.py', '.Rapp.history', 'data_preprocessing_template', 'untitled', 'categorical_data.R', 'data_preprocessing_template My']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 10 - Model Selection & Boosting
# Directories: ['Section 40 - Model Selection', 'Section 39 -------------------- Part 10 - Model Selection --------------------', 'Section 42 - Part Recap', 'Section 41 - XGBoost']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 10 - Model Selection & Boosting/Section 40 - Model Selection
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 10 - Model Selection & Boosting/Section 39 -------------------- Part 10 - Model Selection --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 10 - Model Selection & Boosting/Section 42 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 10 - Model Selection & Boosting/Section 41 - XGBoost
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 8 - Deep Learning
# Directories: ['Section 33 - Convolutional Neural Networks (CNN)', 'Section 32 - Artificial Neural Networks (ANN)', 'Section 34 - Part Recap', 'Section 31 -------------------- Part 8 - Deep Learning --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 8 - Deep Learning/Section 33 - Convolutional Neural Networks (CNN)
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 8 - Deep Learning/Section 32 - Artificial Neural Networks (ANN)
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 8 - Deep Learning/Section 34 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 8 - Deep Learning/Section 31 -------------------- Part 8 - Deep Learning --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression
# Directories: ['Section 4 - Simple Linear Regression', 'Section 5 - Multiple Linear Regression', 'Section 8 - Part Recap', 'Section 7 - Evaluating Regression Models Performance', 'Section 6 - Polynomial Regression', 'Section 3 -------------------- Part 2 - Regression --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 4 - Simple Linear Regression
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 5 - Multiple Linear Regression
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 8 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 7 - Evaluating Regression Models Performance
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 6 - Polynomial Regression
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 2 - Regression/Section 3 -------------------- Part 2 - Regression --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 6 - Reinforcement Learning
# Directories: ['Section 26 - Thompson Sampling', 'Section 25 - Upper Confidence Bound (UCB)', 'Section 27 - Part Recap', 'Section 24 -------------------- Part 6 - Reinforcement Learning --------------------']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 6 - Reinforcement Learning/Section 26 - Thompson Sampling
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 6 - Reinforcement Learning/Section 25 - Upper Confidence Bound (UCB)
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 6 - Reinforcement Learning/Section 27 - Part Recap
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Machine Learning A-Z/Part 6 - Reinforcement Learning/Section 24 -------------------- Part 6 - Reinforcement Learning --------------------
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/AI知识框架.mindnode
# Directories: ['QuickLook', 'resources', 'style.mindnodestyle']
# Files: ['contents.xml', 'viewState.plist']
#
# Current Path: /Users/hkmac/Desktop/数据分析/AI知识框架.mindnode/QuickLook
# Directories: []
# Files: ['Preview.jpg']
#
# Current Path: /Users/hkmac/Desktop/数据分析/AI知识框架.mindnode/resources
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/AI知识框架.mindnode/style.mindnodestyle
# Directories: []
# Files: ['contents.xml', 'metadata.plist']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Data Science.mindnode
# Directories: ['QuickLook', 'resources', 'style.mindnodestyle']
# Files: ['contents.xml', 'viewState.plist']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Data Science.mindnode/QuickLook
# Directories: []
# Files: ['Preview.jpg']
#
# Current Path: /Users/hkmac/Desktop/数据分析/Data Science.mindnode/resources
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数据分析/Data Science.mindnode/style.mindnodestyle
# Directories: []
# Files: ['contents.xml', 'metadata.plist']
#
# Current Path: /Users/hkmac/Desktop/数据分析/SQL
# Directories: ['SQL Course Materials']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/数据分析/SQL/SQL Course Materials
# Directories: []
# Files: ['create-db-inventory.sql', 'create-db-invoicing.sql', 'create-databases.sql', 'create-db-hr.sql', 'create-db-store.sql']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github
# Directories: ['Machine Learning', 'Python', 'Project', '.ipynb_checkpoints', '.git']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning
# Directories: ['ML_Andrew Ng']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning/ML_Andrew Ng
# Directories: ['ex1']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning/ML_Andrew Ng/ex1
# Directories: ['ex1']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning/ML_Andrew Ng/ex1/ex1
# Directories: ['lib']
# Files: ['ex1.m', 'computeCostMulti.m', 'computeCost.m', 'warmUpExercise.m', 'gradientDescentMulti.m', '.DS_Store', 'featureNormalize.m', 'plotData.m', 'token.mat', 'normalEqn.m', 'submit.m', 'ex1data1.txt', 'gradientDescent.m', 'ex1data2.txt', 'ex1_multi.m']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning/ML_Andrew Ng/ex1/ex1/lib
# Directories: ['jsonlab']
# Files: ['submitWithConfiguration.m', 'makeValidFieldName.m']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Machine Learning/ML_Andrew Ng/ex1/ex1/lib/jsonlab
# Directories: []
# Files: ['saveubjson.m', 'varargin2struct.m', 'jsonopt.m', 'mergestruct.m', 'loadjson.m', 'LICENSE_BSD.txt', 'ChangeLog.txt', 'README.txt', 'savejson.m', 'AUTHORS.txt', 'loadubjson.m']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python
# Directories: ['Libraries', 'Package Management', '.ipynb_checkpoints', 'Modules']
# Files: ['Formatting.ipynb', 'Function.ipynb', '.DS_Store', 'Jupyter Notebook.ipynb', 'Generators.ipynb', 'OOP.ipynb', 'Common Problem with Strings.ipynb', 'Variable Scope.ipynb', 'Data Structure.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Libraries
# Directories: ['.ipynb_checkpoints', 'Pandas']
# Files: ['.DS_Store', 'NumPy.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Libraries/.ipynb_checkpoints
# Directories: []
# Files: ['Data Analysis using Pandas-checkpoint.ipynb', 'Matplotlib-checkpoint.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Libraries/Pandas
# Directories: ['.ipynb_checkpoints']
# Files: ['.DS_Store', 'avocado.csv', 'Data Analysis using Pandas.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Libraries/Pandas/.ipynb_checkpoints
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Package Management
# Directories: []
# Files: ['pip -Package Management System', 'conda -Package Manager ']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/.ipynb_checkpoints
# Directories: []
# Files: ['Data Structure-checkpoint.ipynb', 'Formatting-checkpoint.ipynb', 'Common Problem with Strings-checkpoint.ipynb', 'OOP-checkpoint.ipynb', 'Virtual Environments-checkpoint.ipynb', 'Jupyter Notebook-checkpoint.ipynb', 'Function-checkpoint.ipynb', 'Data Type-checkpoint.ipynb', 'Variable Scope-checkpoint.ipynb', 'Generators-checkpoint.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Modules
# Directories: ['.ipynb_checkpoints']
# Files: ['OS Module.ipynb', 'Random.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Python/Modules/.ipynb_checkpoints
# Directories: []
# Files: ['Random-checkpoint.ipynb', 'OS Module-checkpoint.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Project
# Directories: ['.ipynb_checkpoints']
# Files: ['Time Series Analysis of Electric Production.ipynb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/Project/.ipynb_checkpoints
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.ipynb_checkpoints
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs', 'branches']
# Files: ['ORIG_HEAD', 'config', 'HEAD', 'description', 'index', 'COMMIT_EDITMSG', 'FETCH_HEAD']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects
# Directories: ['61', '0d', '92', '66', '6f', '32', '58', '0b', '94', '0e', '9d', 'd9', 'bb', 'b3', 'b4', 'bc', 'ae', 'e5', 'f3', 'eb', 'fb', '4e', '20', 'pack', '7d', '29', '42', '7b', '7e', '75', '2a', '2f', '07', '9a', '31', 'info', '62', '30', '6d', '01', '06', '0f', 'd3', 'b8', 'dd', 'a9', 'b7', 'a6', 'a1', 'ea', 'f7', '79', '8c', '85', '76', '49', '2e', '7f']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/61
# Directories: []
# Files: ['9ff03989f026e3351feb18078793d8d2178e95']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/0d
# Directories: []
# Files: ['1399469744ca7be15adba9af6b4a90dfc66c48', 'b9a641b54d7e52634304966b2f35c60ec7a8ed']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/92
# Directories: []
# Files: ['ad2e024109dded7cadda3fd508b527e5030afa', 'ae051d206369e7cb0466b160f9a4e0c10f2919']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/66
# Directories: []
# Files: ['4f9d477fde01b94b83b3c26bcf88401a82240b']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/6f
# Directories: []
# Files: ['af85005bf3bb8e826d55edfd12f0a4c4ac2853']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/32
# Directories: []
# Files: ['d66cbc0eec1ffa82a1f95d5d136353c353dd9b']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/58
# Directories: []
# Files: ['f410d15a3773efc41fafba9211b386839c636c', '6f540d09e6178d3de8c3fef86f8a071a402152']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/0b
# Directories: []
# Files: ['ebd8de714281877ffa3dfc90cac8f93fb44874', '6a41d2b26a09fdf81fa5fa07ce4947e9273ecc']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/94
# Directories: []
# Files: ['a30b7538745b121eb6496dbb5e4ff413bf9143']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/0e
# Directories: []
# Files: ['c5ecaaee75905c63c02c2e5fb0aea2c7fc526a']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/9d
# Directories: []
# Files: ['d3fc7bc4ff19568019b38307a7f96c90a29e8c']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/d9
# Directories: []
# Files: ['a3d68f019d882020156c47b61328b673abec5f']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/bb
# Directories: []
# Files: ['ee7edfb5a1b459b51a4e0d9ae5ca90ab21323e', '5d07297996e28b7d1f3270a03be9e0f958e8b3', '894bd7ba81b87334cbaf57f5eb67ecca98c5fb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/b3
# Directories: []
# Files: ['e7980f1298281a8a25ba74f00de0c6d1e01dc0']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/b4
# Directories: []
# Files: ['479a22b9e9326826210a16e15ee38241e5ca98']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/bc
# Directories: []
# Files: ['ec867a82865b87b393fb7edf2a10b34722b0c2']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/ae
# Directories: []
# Files: ['ddd0b90e0b832b7ee86ceeec39a1e5dc6fe030']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/e5
# Directories: []
# Files: ['e1b7e0d949fc234714127f54697869b1d6a2ff']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/f3
# Directories: []
# Files: ['423983592faed4bdf825af818bf364fa53a8ba']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/eb
# Directories: []
# Files: ['ad144e14ac5454b156c6e2fef8d69cbe300b54', '0a022f8806a37ed1ccf15ad9477fa84f269011']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/fb
# Directories: []
# Files: ['e8dbc7313b096c32c4a46b348d69579d58f813', 'e7abdf4115cf2e2e1bd3e31e898261710e53d7']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/4e
# Directories: []
# Files: ['0f34f43c919e685e8b5a504bec0ddc66cb0439']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/20
# Directories: []
# Files: ['fa94b7187efd8fc684b9693d167a9a0577e795']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/pack
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/7d
# Directories: []
# Files: ['af43090f2848e700c02c6315c656c3ed650fd2']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/29
# Directories: []
# Files: ['46d7ef90902abc99f3deec21e74b44bcc57a98']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/42
# Directories: []
# Files: ['38ee14149e2b604e51bfad1477797a1891e54e', '798c0acaa0be7fbffeb3b11c530084fcfad159']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/7b
# Directories: []
# Files: ['4f7327c6f67832130bd9a3cc0fa8ac44f905fb']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/7e
# Directories: []
# Files: ['8407617d78cf22d45eaac0d19517ceb1cecbb2']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/75
# Directories: []
# Files: ['45b5cfbd5b558424e6e0d379fbd07d1aeda3e9', '0fca8804abb4572877031b26ce7d266349e762']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/2a
# Directories: []
# Files: ['630eb357196afb227d7d2624528aa5f19b3991']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/2f
# Directories: []
# Files: ['d64429bf421126b7000c94ce0f6fd186fbd01f']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/07
# Directories: []
# Files: ['824f5c3f6e541c35a6b50b8156539683886aac']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/9a
# Directories: []
# Files: ['5c2b66ca434cd1865c9db10feb68b7f94b0482']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/31
# Directories: []
# Files: ['dc9c52d15df2963529ae5b660eea80c064dab4', '10ab476844de3f1d42e81cdfb0a77772d51925']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/info
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/62
# Directories: []
# Files: ['6cde3362f63a9d9dd521c605c21ed88746ee5a']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/30
# Directories: []
# Files: ['349492904d6ab76fc13a00d78259b0fb9f8b6a']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/6d
# Directories: []
# Files: ['e610043d9a0ecd0b3c64b0105b079d7c313223']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/01
# Directories: []
# Files: ['551155991325bedb9729a46c5324b1f17a22ef']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/06
# Directories: []
# Files: ['f65f25802a1bc0847f6fb56777cece63bc7cfa']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/0f
# Directories: []
# Files: ['88ccb611f840ba9283e0de2a26b6cb9b8fde02']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/d3
# Directories: []
# Files: ['2cd8efdc07286dd16072ea3ff4cd0da7094680']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/b8
# Directories: []
# Files: ['cd5374313afb17f0f4c717e8e15b97cbee6643']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/dd
# Directories: []
# Files: ['8bb2bfda8ff093d388a8aeee18c3d6c81242dc']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/a9
# Directories: []
# Files: ['eb0f3a7ffe00462c99692cda0ea7e4032c7347', '78403310445cc6dd4d8eeb1660b3acf49d04c5']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/b7
# Directories: []
# Files: ['82cb201edfc1d771bc94b5ed848cbcfc703aa7']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/a6
# Directories: []
# Files: ['f241439bd33bc3d9e61f144ad96e422cc97cda']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/a1
# Directories: []
# Files: ['3b0fa4fb2b0e67c41e3e1cfb8974f76671a74f']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/ea
# Directories: []
# Files: ['ec433fc8a9bde066d9b6391adf656284153ace']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/f7
# Directories: []
# Files: ['33012d28026cec5a89f681ae31dea3434ab5c0']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/79
# Directories: []
# Files: ['e9a807edd86632d58aa2ec832e190d997f43e7']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/8c
# Directories: []
# Files: ['bd11b760cdf92885fcf786c070290808457266']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/85
# Directories: []
# Files: ['62c84414b068b21c3380c12c88703436d412c3']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/76
# Directories: []
# Files: ['3ed6602bd214cb691f05683e4a5465fa12deae']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/49
# Directories: []
# Files: ['3b49abc362f94eb7fddf5d984d4497328b4325']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/2e
# Directories: []
# Files: ['04c10ace9b4c5627ed472a202685fda54036e4']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/objects/7f
# Directories: []
# Files: ['398767a2d03cb2a7e616f577b3930639cde402']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/info
# Directories: []
# Files: ['exclude']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/logs
# Directories: ['refs']
# Files: ['HEAD']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/logs/refs
# Directories: ['heads', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/logs/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/logs/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/logs/refs/remotes/origin
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/hooks
# Directories: []
# Files: ['commit-msg.sample', 'pre-rebase.sample', 'pre-commit.sample', 'applypatch-msg.sample', 'fsmonitor-watchman.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-push.sample', 'update.sample']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/refs
# Directories: ['heads', 'tags', 'remotes']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/refs/heads
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/refs/tags
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/refs/remotes
# Directories: ['origin']
# Files: []
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/refs/remotes/origin
# Directories: []
# Files: ['master']
#
# Current Path: /Users/hkmac/Desktop/Carzy Allen Github/.git/branches
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/数理统计
# Directories: []
# Files: ['赤裸裸的统计学 （14.4MB-高清PDF）.pdf']
#
# Current Path: /Users/hkmac/Desktop/Python
# Directories: ['书籍', '利用Python进行数据分析', '库', '.ipynb_checkpoints']
# Files: ['.DS_Store', 'OOP.ipynb', 'Python Basic.ipynb', 'time_series_examples.dta']
#
# Current Path: /Users/hkmac/Desktop/Python/书籍
# Directories: []
# Files: ['.DS_Store', 'Python数据分析与挖掘实战 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'Python编程：从入门到实践23M超清版 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', '《利用Python进行数据分析》.(Wes McKinney).[PDF]@jb51.net 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'Python-Cheat-Sheet.pdf']
#
# Current Path: /Users/hkmac/Desktop/Python/利用Python进行数据分析
# Directories: ['MarkdownPhotos', 'Chapter-11', 'Chapter-04', 'datasets', 'Chapter-05', 'examples', 'Chapter-12', 'Chapter-14', 'Chapter-07']
# Files: ['.Rhistory', '.DS_Store', 'README.md', '.gitignore']
#
# Current Path: /Users/hkmac/Desktop/Python/利用Python进行数据分析/MarkdownPhotos
# Directories: ['chp03', 'chp04']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/Python/利用Python进行数据分析/MarkdownPhotos/chp03
# Directories: []
# Files: ['屏幕快照 2017-10-24 上午9.38.24.png', '屏幕快照 2017-10-25 下午2.04.40.png', '屏幕快照 2017-10-24 上午9.48.27.png', '屏幕快照 2017-10-25 下午1.59.36.png', '屏幕快照 2017-10-24 上午9.50.36.png', '屏幕快照 2017-10-25 下午2.01.37.png']
#
# Current Path: /Users/hkmac/Desktop/Python/利用Python进行数据分析/MarkdownPhotos/chp04
# Directories: []
# ...
# Directories: []
# Files: ['HUANG Zishuo.docx']
#
# Current Path: /Users/hkmac/Desktop/研究生/PSI保险
# Directories: []
# Files: ['PSI-ID_ZishuoP19004395_PSI-DE10019.pdf', 'ConfirmationLetter_Zishuo_PSI-DE10019.pdf', 'IdCard_Zishuo_PSI-DE10019.pdf']
#
# Current Path: /Users/hkmac/Desktop/研究生/签证
# Directories: ['老师CV']
# Files: ['签证信息表(2页)-美世教育.xls', 'study plan 1.doc', '.DS_Store', '签证问题--硕博--美世教育.doc', '收入证明模板.doc', 'study plan.doc', '收入证明2模板.doc', '签证4包-美世教育.pdf']
#
# Current Path: /Users/hkmac/Desktop/研究生/签证/老师CV
# Directories: []
# Files: ['Liangfei-Qiu-CV.pdf', 'anuj-kumar-cvBusiness Database Systems I.pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍
# Directories: ['Machine Learning', '数据分析', 'Python', '线性代数', 'English', 'Data Science', 'Statistic', 'IE', 'SQL']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Machine Learning
# Directories: ['全部 12 notes 译文原稿Word文档打包']
# Files: ['Mathematics for ML.pdf', 'MLY-zh-cn.pdf', '.DS_Store', '统计学习方法 - 李航.pdf', '机器学习_周志华.pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Machine Learning/全部 12 notes 译文原稿Word文档打包
# Directories: []
# Files: ['cs229-notes1.docx', 'cs229-notes12.docx', 'cs229-notes7b.docx', 'cs229-notes6.docx', 'cs229-notes9.docx', 'cs229-notes5.docx', 'cs229-notes4.docx', 'cs229-notes8.docx', 'cs229-notes7a.docx', 'cs229-notes3.docx', 'cs229-notes10.docx', 'cs229-notes11.docx', 'cs229-notes2.docx']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/数据分析
# Directories: []
# Files: ['谁说菜鸟不会数据分析工具篇-简版电子书 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', '数据挖掘导论(完整版).Introduction.To.Data.Min(1).pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Python
# Directories: []
# Files: ['用Python进行自然语言处理(中文) 关注公众号：数据挖掘及分析，获取更多干货.pdf', 'pythonbook.pdf', 'PYTHON自然语言处理【中文版】 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', '.DS_Store', 'Beginning_Python_Visualization__Crafting_Visual_Transformation_Scripts 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'Python学习手册(第4版) 中文版.pdf', '深入浅出：使用Python编程 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'visualizing_data 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.pdf', 'Python金融大数据分析 带索引书签目录高清版 关注微信公众号：数据挖掘及分析  回复“干货”获取更过免费资源.PDF']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/线性代数
# Directories: []
# Files: ['Linear Algebra with Applications, 9th Edition by Steven J. Leon.pdf', '1.CS229-LinearAlgebra.pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/English
# Directories: []
# Files: ['.DS_Store', 'Verbal.Advantage.pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Data Science
# Directories: []
# Files: ['artofdatascience.pdf', 'Data Science for Business What you need to know about data mining and data-analytic thinking.pdf', 'Reinforcement Learning - An Introduction%28Second edition%2C Draft%29.pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Statistic
# Directories: ['120676商务统计学（英文版第5版）学生资源']
# Files: ['高等数学上.pdf', '高等数学下.pdf', '.DS_Store', 'REVIEW OF STATISTICAL TOOLS-2019.pdf', 'Handbook.pdf', '2.CS229-Prob.pdf', 'BasicBusinessStatisticsConceptsandApplications4thEditionbyBerenson.pdf', 'Basic Business Statistics Concepts and Applications 14th.pdf', '数理统计学教程（陈希孺倪国熙）.pdf', '概率论与数理统计(浙大第四版).pdf', 'CS229T斯坦福统计学习理论笔记.pdf', 'ESLII_print10.pdf', '概率论与数理统计(第四版).pdf']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/Statistic/120676商务统计学（英文版第5版）学生资源
# Directories: []
# Files: ['largest Bonds.xls', 'Breakstw.xls', 'Wonderlic.xls', 'Dinner.xls', 'SH14-1.xls', 'Pallet.xls', 'Petfood.xls', 'Poisson.xls', 'BBCost.xls', 'Drink.xls', 'OmniPower.xls', 'Myeloma.xls', 'Protein.xls', 'Concrete1.xls', 'Chi-Square Worksheets.xls', 'SH14-2.xls', 'Absolute Differences.xls', 'PizzaTime.xls', 'Moving.xls', 'Probabilities.xls', 'Luggage.xls', 'UndergradSurvey.xls', 'Rent.xls', 'SH10-2.xls', 'Chicken.xls', 'SH8.xls', 'DarkChocolate.xls', 'Standby.xls', 'run.exe', 'Sponge.xls', 'SH9.xls', 'Harnswell.xls', 'WholeFoods1.xls', 'Energy.xls', 'SH10-1.xls', 'SpWater.xls', 'Delivery.xls', 'GasPrices.xls', 'Colaspc.xls', 'AUTORUN.INF', 'Sporting.xls', 'SUV.xls', 'BBRevenue.xls', 'AAAMileage.xls', 'Order.xls', 'States.xls', 'Golfball.xls', 'Pen.xls', 'House1.xls', 'Utility.xls', 'Bank1.xls', 'MedRec.xls', 'Parachute.xls', 'Force.xls', 'Advertise.xls', 'Restaurants.xls', 'NBA2008.xls', 'Angle.xls', 'House3.xls', 'Stocks2008.xls', 'Movie.xls', 'Spending.xls', 'House2.xls', 'CIE Proportion.xls', 'Bank2.xls', 'Z Two Proportions.xls', 'GlenCove.xls', 'BestRest.xls', 'Tensile.xls', 'CoffeeDrink.xls', 'Anscombe.xls', 'TVChannels.xls', 'Coffee.xls', 'MixedCosts.xls', 'FundTran.xls', 'Canister.xls', 'Sealant.xls', 'Tukey-Kramer.xls', 'CIE sigma known.xls', 'Sample Size Mean.xls', 'T Mean.xls', 'Movies.xls', 'RandXBarChart.xls', 'CDYield.xls', 'Unemployment.xls', 'Warehse.xls', 'Errorspc.xls', 'ERWaiting.xls', 'Neighbor.xls', 'ElecUse.xls', 'Circulation.xls', 'Auto.xls', 'ThemeParks.xls', 'Bayes.xls', 'GCRoslyn.xls', 'Crack.xls', 'CollegeTuition.xls', 'Trashbags.xls', 'BB2007.xls', 'CIEandPIforSLR.xls', 'Redwood.xls', 'Wait.xls', 'FirstQuarter.xls', 'Furniture.xls', 'CIEandPIforMR.xls', 'Chi-Square.xls', 'O Ring.xls', 'CIE sigma unknown.xls', 'Site.xls', 'CEO.xls', 'Colleges Basketball.xls', 'RudyBird.xls', 'VB.xls', 'NYSE.xls', 'Digitalcameras.xls', 'Mileage.xls', 'Savings Rate.xls', 'Banking.xls', 'Pumpkin.xls', 'Steel.xls', 'Closing.xls', 'Tuition2006.xls', 'Trade.xls', 'Yarn.xls', 'SH12.xls', 'Invoices.xls', 'Foulspc.xls', 'Pooled-Variance T.xls', 'Keyboard Defects.xls', 'Textbook.xls', 'Cost of Living.xls', 'DowMarketCap.xls', 'SH13.xls', 'Teabags.xls', 'PropertyTaxes.xls', 'Transmit.xls', 'Z Mean.xls', 'MoviePrices.xls', 'F Two Variances.xls', 'GradSurvey.xls', 'Phillies.xls', 'Tea3.xls', 'Binomial.xls', 'Training.xls', 'readme.txt', 'Moisture.xls', 'Expected Value.xls', 'BankTime.xls', 'Normal.xls', 'Insurance.xls', 'Covariance.xls', 'Hotel1.xls', 'Phone.xls', 'Boxplot.xls', 'Sample Size Proportion.xls', 'Telespc.xls', 'Trough.xls', 'Intaglio.xls', 'Granule.xls', 'Cola.xls', 'Wal-Mart.XLS', 'Supermarket.xls', 'Measurement.xls', 'Hotel2.xls', 'Hotels.xls', 'Sedans.xls', 'p Chart.xls', 'NPP.xls', 'DomesticBeer.xls', 'Perform.xls', 'Transport.xls', 'Tax.xls', 'Correlation.xls', 'Invoice.xls', 'Drill.xls', 'BankYield.xls', 'SH2.xls', 'StackedAndUnstacked.xls', 'GPIGMAT.xls', 'Z Proportion.xls', 'Separate-Variance T.xls', 'Times.xls', 'HospAdm.xls', 'Mutual Funds.xls', 'Bulbs.xls', 'StudyTime.xls']
#
# Current Path: /Users/hkmac/Desktop/常用书籍/IE
# Directories: []
# Files: ['IEHANDBOOK(3rd).pdf']
# Current Path: /Users/hkmac/Desktop/常用书籍/SQL
# Directories: []
# Files: ['高性能MySQL第三版.超清晰中文.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请
# Directories: ['Offer', '简历', '澳洲', '网申', '面试', '美国', '学校', '学习计划']
# Files: ['.DS_Store', 'GS (1).xmind', 'Reference Letter Abstract (1).doc', '文书题目.docx', 'Reference Letter Abstract.doc', '黄子朔_2019年秋季网申 1.docx', 'GS.xmind']
#
# Current Path: /Users/hkmac/Desktop/留学申请/Offer
# Directories: []
# Files: ['.DS_Store', 'CWRU AD.pdf', 'Clark University Graduate Admissions.pdf', 'Stevens Institute of Technology Graduate Admissions.pdf', '佛罗里达ISOM黄子朔.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/简历
# Directories: ['过程']
# Files: ['.DS_Store', '个人简历 (1).docx', '个人简历.docx', '黄子朔_CV - revised.docx', '个人简历（背景提升项目）.docx', '黄子朔_CV - 学生反馈.docx', '个人简历 (1).pdf', '个人简历.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/简历/过程
# Directories: []
# Files: []
#
# Current Path: /Users/hkmac/Desktop/留学申请/澳洲
# Directories: []
# Files: ['算数平均分.xlsx', '支付宝微信付款方式.pdf', '研究生意向表.xlsx', '研究生意向表 (1).xlsx', 'ppt for YSU plus (1).pdf', 'ppt for YSU plus.pdf', '支付宝微信付款方式 (1).pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申
# Directories: ['UCSD', '南加州', 'UF', 'CRSW', 'RPI PS', '罗村', '网申-斯蒂文斯理工', '专业绩点', '维克森林', 'UCI', '网申-克拉克']
# Files: ['.DS_Store', 'PS RPI最终.docx', 'PS第一版.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/UCSD
# Directories: []
# Files: ['UCSD前面.docx', '网申问题.docx', 'UCSD.docx', '网申问题 1.docx', 'UCSD jordan.docx', 'UCSD-20190327.docx', 'UCSD-20190327 1.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/南加州
# Directories: []
# Files: ['南加州分析学.docx', 'USC-Analytics.docx', 'USC-Analytics最终版.docx', '南加州ads.docx', 'USC-Applied Data Science.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/UF
# Directories: []
# Files: ['.DS_Store', 'PS_Florida.docx', '佛罗里达Why school.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/CRSW
# Directories: []
# Files: ['题目.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/RPI PS
# Directories: []
# Files: ['PS_RPI.docx', 'PS伦斯勒.docx', 'PS_RPI-学生反馈.docx', 'Allen.docx', 'PS_RPI 1.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/罗村
# Directories: []
# Files: ['黄子朔Rochester-essay 2.docx', 'Rochester PS.docx', '黄子朔Rochester-essay 1.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/网申-斯蒂文斯理工
# Directories: []
# Files: ['斯蒂文斯理工网申素材.docx', 'MIS630 Data and Knowledge Management Fall 2014.doc', 'PS_SIT.docx', '斯蒂文斯课程简介.docx', '斯蒂文斯理工网页信息.docx', '斯蒂文斯理工网申素材 .docx', '黄子朔_2019年秋季网申.docx', 'PS_SIT-revised.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/专业绩点
# Directories: []
# Files: ['屏幕快照 2019-02-14 12.05.19.png', '专业课.xlsx', '屏幕快照 2019-02-14 11.56.51.png']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/维克森林
# Directories: []
# Files: ['WFU-essay 3.docx', 'WFU PS 1.docx', 'WFU-essay 2.docx', 'WFU-essay 2最终.docx', 'WFU PS3 .docx', 'WFU PS2.docx', 'WFU-essay 1.docx', 'WFU-essay 3最终.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/UCI
# Directories: []
# Files: ['UCI-essay 2最终版.docx', 'essay uci修改.docx', 'UCI-essay 1-20190227.docx', 'MSBA-Flier.pdf', '.DS_Store', 'UCI-essay 2.docx', 'UCI-essay 1.docx', 'UCI素材.docx', 'UCI why school+leadership.docx', 'essay2修改.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/网申/网申-克拉克
# Directories: []
# Files: ['克拉克大学PS.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/面试
# Directories: ['UF面试', 'WFU KIRA面试']
# Files: ['CWRU kira面经.docx', '.DS_Store', 'CWRU MSBA kira 面经.docx', '问题～.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/面试/UF面试
# Directories: []
# Files: ['UF面试回顾.docx', '.DS_Store', 'UF面试素材.docx', 'UF ISOM.docx', 'PS_Florida.pdf', 'HZS-CV.pdf', 'WechatIMG727.png', 'UFL 面试.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/面试/WFU KIRA面试
# Directories: []
# Files: ['WFU MSBA 面经 12.9更新.docx', 'WFU MSBA KIRA面經.docx', 'WFU面经.docx', 'WFU面经建议.docx', '没思路的题.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/美国
# Directories: ['在读证明', '推荐信']
# Files: ['申请材料清单.docx', '.DS_Store', '申请材料清单 (1).docx', '黄子朔_2019年秋季网申 (1).docx', '黄子朔_2019年秋季网申.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/美国/在读证明
# Directories: []
# Files: ['%E4%B8%AD%E6%96%87%E5%9C%A8%E8%AF%BB%E8%AF%81%E6%98%8E%E6%A8%A1%E6%9D%BF.doc', '.DS_Store', '%E4%B8%AD%E8%8B%B1%E6%96%87%E5%9C%A8%E8%AF%BB%E8%AF%81%E6%98%8E%E6%A8%A1%E6%9D%BF (1).doc', '%E4%B8%AD%E6%96%87%E5%9C%A8%E8%AF%BB%E8%AF%81%E6%98%8E%E6%A8%A1%E6%9D%BF (1).doc']
#
# Current Path: /Users/hkmac/Desktop/留学申请/美国/推荐信
# Directories: ['推荐信定稿', '选择学校']
# Files: ['推荐信-IDC.docx', '.DS_Store', '推荐信-Liang Xu (1).docx', '20181105 黄子朔_CV.docx', '推荐信-Liang Xu - revised.pdf', '推荐信-Yumei Hou.docx', '推荐信-Liang Xu.docx', '推荐信-Liang Xu - revised.docx', '推荐信模板 (1).docx', '推荐信——侯老师.docx', '推荐信模板.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/美国/推荐信/推荐信定稿
# Directories: []
# Files: ['推荐信 - 侯老师.docx', '推荐信 - Liang Xu.docx', '推荐信-IDC.docx', 'img-103163706-0001.pdf', 'img-104210611_页面_2.jpg', 'img-104210611_页面_1.jpg']
#
# Current Path: /Users/hkmac/Desktop/留学申请/美国/推荐信/选择学校
# Directories: []
# Files: ['学校查询-子朔.xlsx', '背景分析.docx', '学校选择 (1).xlsx', '背景分析 (1).docx', '学校选择.xlsx', '学校查询-子朔 (1).xlsx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学校
# Directories: ['BA学校信息']
# Files: ['.DS_Store', '学校.xlsx', '专业及终选院校名单确认书-黄子朔2019.2.12.xls', '学校查询-子朔2.xlsx', '学校附加.xlsx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学校/BA学校信息
# Directories: ['伦斯勒', '克拉克', '维克森林']
# Files: ['迈阿密大学商业分析课程.pdf', '个人陈述素材.docx', '.DS_Store', '福特汉姆.pdf', '凯斯西储.pdf', 'BSAN Fall 2018 Spring 2019 Course Schedule_Dec_6_2018.pdf', 'Business+Analytics+M.S..pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学校/BA学校信息/伦斯勒
# Directories: []
# Files: ['伦斯勒.pdf', 'Plan-of-Study-37credits-3.28.18.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学校/BA学校信息/克拉克
# Directories: []
# Files: ['克拉克大学MSBS课程.pdf', '克拉克商业分析简表.pdf', '克拉克商业分析指南.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学校/BA学校信息/维克森林
# Directories: []
# Files: ['维克森林.pdf', '维克森林商业分析介绍.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学习计划
# Directories: ['托福', 'GRE', 'GRE 1.19']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学习计划/托福
# Directories: []
# Files: ['托福备考计划.pdf', '托福考前冲刺计划.pdf', '托福备考计划.docx']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学习计划/GRE
# Directories: []
# Files: ['3000背诵.xlsx', '再要你命3000背诵计划表.xlsx', '备考计划.docx', '时间表.docx', 'GRE方法.docx', 'GRE总结.docx', '三周冲刺时间表.docx', '三周冲刺时间表.pdf']
#
# Current Path: /Users/hkmac/Desktop/留学申请/学习计划/GRE 1.19
# Directories: []
# Files: ['.DS_Store', 'GRE冲刺计划.docx', '课程表.xlsx']
#
# Current Path: /Users/hkmac/Desktop/Exam1
# Directories: []
# Files: ['TruckDataSet.xlsx', 'Ex1_Code_Formula Sheet.pdf', 'Exam1Review_Fall2019_Answers.pdf', 'Exam1Review_Fall2019.pdf']
#
# Current Path: /Users/hkmac/Desktop/SQL Course Materials
# Directories: []
# Files: ['create-db-inventory.sql', 'create-db-invoicing.sql', 'create-databases.sql', 'create-db-hr.sql', 'create-db-store.sql']
#
# Current Path: /Users/hkmac/Desktop/工作
# Directories: ['Self Materials', 'Job fair', '企业资料', 'Career Analysis.mindnode']
# Files: ['Master Excel Document.xlsx', '.DS_Store', 'Interview Preparation Checklist.pdf']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials
# Directories: ['Cover letter example', 'Resume', 'Cover letter Info Tech']
# Files: ['cover letter.docx', 'Elevator pitch.docx', '.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Cover letter example
# Directories: []
# Files: ['Cover Letter Examples 4-6.pdf', 'Cover Letter Example 2 - With Subheadings.docx', 'Cover Letter Example 1', 'Cover Letter Example 3 - With Subheadings.docx']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Resume
# Directories: ['旧版本', 'Template', 'BSC资源']
# Files: ['.DS_Store', 'Resume_Zishuo_Huang.pdf', 'Resume_Zishuo_Huang.docx']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Resume/旧版本
# Directories: []
# Files: ['ZISHUO HUANG原始版.docx', 'ZISHUO HUANG After 1st BSC.docx']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Resume/Template
# Directories: []
# Files: ['ISOM Resume Template.docx', 'Accomplishment archive.xlsx', 'resume example1.jpg', 'STAR and START Method FINAL.PDF', 'Resume Action Words FINAL.pdf']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Resume/BSC资源
# Directories: []
# Files: ['BCS Accomplishment Archive_BLANK.xlsx', 'STAR结构.png', 'BCS Accomplishment Archive_EXAMPLE.xlsx', 'STAR and START Method FINAL.PDF']
#
# Current Path: /Users/hkmac/Desktop/工作/Self Materials/Cover letter Info Tech
# Directories: []
# Files: ['Coverletter_Zishuo_Huang.docx', 'Coverletter_Zishuo_Huang.pdf']
#
# Current Path: /Users/hkmac/Desktop/工作/Job fair
# Directories: ['Gator Graduate', 'Career Fellows']
# Files: ['AIS Mixer_Showcase Company Cheatsheet.pdf', '.DS_Store', 'Career showcase.xlsx', 'ISOM Mixer - Recruiting Info.xlsx']
#
# Current Path: /Users/hkmac/Desktop/工作/Job fair/Gator Graduate
# Directories: []
# Files: ['ISOM Resume Template.docx', 'Job Application Tracker.xlsx', 'Gator Graduate - Hiring Information.pdf']
#
# Current Path: /Users/hkmac/Desktop/工作/Job fair/Career Fellows
# Directories: []
# Files: ['BCS - Student Code of Conduct Fall 2018.pdf', '2019 Career Fellows Requirements.pptx']
#
# Current Path: /Users/hkmac/Desktop/工作/企业资料
# Directories: ['OPIE']
# Files: ['.DS_Store']
#
# Current Path: /Users/hkmac/Desktop/工作/企业资料/OPIE
# Directories: []
# Files: ['Intern Job Descr_2_OPIE data BI_Spring2020_Ani.pdf']
#
# Current Path: /Users/hkmac/Desktop/工作/Career Analysis.mindnode
# Directories: ['QuickLook', 'resources', 'style.mindnodestyle']
# Files: ['contents.xml', 'viewState.plist']
#
# Current Path: /Users/hkmac/Desktop/工作/Career Analysis.mindnode/QuickLook
# Directories: []
# Files: ['Preview.jpg']
#
# Current Path: /Users/hkmac/Desktop/工作/Career Analysis.mindnode/resources
# Directories: []
# Files: ['CC8F89B9-C2A2-41D9-A853-2E7E13F6D34B.png', '30540E28-E513-4BE9-B958-9ED01CEA0C01.png']
#
# Current Path: /Users/hkmac/Desktop/工作/Career Analysis.mindnode/style.mindnodestyle
# Directories: []
# Files: ['contents.xml', 'metadata.plist']

# %% [markdown]
# It start at the current path: /Users/hkmac/Desktop. Then print out all the directories within the desktop, and all of the files
#
# Then it goes down to each of the directories one at a time
#
# This is useful for locating a file that you can’t remember where it was. If you had a web app, and you wanted to keep track of the file info within a certain directory structure, then you could to thru the os.walk method and go thru all files and folders and collect file information.

# %%
# Access home directory location by grabbing home environment variable
# Returns a path
print(os.environ.get('HOME'))
# Out:
# /Users/hkmac

# %%
# To properly join two files together use os.path.join()
file_path = os.path.join(os.environ.get('HOME'), 'test.txt')
# the benefit of os.path.join, is it takes the guess work out of inserting a slash

# %%
os.chdir('/Users/hkmac')

# %%
print(file_path)
# 暂时先不create this file, 见关于file的内容中
# Out:
# /Users/hkmac/test.txt

# %%
# os.path has other useful methods
# This will grab filename of any path we are working on
os.path.basename('/tmp/test.txt')
# Out:
# 'test.txt'

# %%
# returns the directoryname /tmp
os.path.dirname('/tmp/test.txt')

# %%
# returns both the directory and the file as a tuple
os.path.split('/tmp/test.txt')
# Out:
# ('/tmp', 'test.txt')

# %%
# returns a boolean, if a file exists
os.path.exists('/tmp/test.txt')
# Out:
# False

# %%
# returns False, if it is a directory
os.path.isdir('/tmp/test.txt')
# Out:
# False

# %%
# if it is a file
os.path.isfile('/tmp/test.txt')
# Out:
# False

# %%
os.path.splitext('/tmp/test.txt')
# Splits file route of the path and the extension
# returns (‘/tmp/test’, ‘.txt’)
# This is alot easier than parsing out the extension. Splitting off and taking the first value is much better.
# Very useful for file manipulation
# Out:
# ('/tmp/test', '.txt')
