# %%
import tensorflow as tf
import jieba
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
data = open('/Users/hkmac/Desktop/poetry.txt').read()

# %%
data[:600]
# Out:
# '寒随穷律变，春逐鸟声开。初风飘带柳，晚雪间花梅。碧林青旧竹，绿沼翠新苔。芝田初雁去，绮树巧莺来。\n晚霞聊自怡，初晴弥可喜。日晃百花色，风动千林翠。池鱼跃不同，园鸟声还异。寄言博通者，知予物外志。\n一朝春夏改，隔夜鸟花迁。阴阳深浅叶，晓夕重轻烟。哢莺犹响殿，横丝正网天。珮高兰影接，绶细草纹连。碧鳞惊棹侧，玄燕舞檐前。何必汾阳处，始复有山泉。\n夏律昨留灰，秋箭今移晷。峨嵋岫初出，洞庭波渐起。桂白发幽岩，菊黄开灞涘。运流方可叹，含毫属微理。\n寒惊蓟门叶，秋发小山枝。松阴背日转，竹影避风移。提壶菊花岸，高兴芙蓉池。欲知凉气早，巢空燕不窥。\n爽气浮丹阙，秋光澹紫宫。衣碎荷疏影，花明菊点丛。袍轻低草露，盖侧舞松风。散岫飘云叶，迷路飞烟鸿。砌冷兰凋佩，闺寒树陨桐。别鹤栖琴里，离猿啼峡中。落野飞星箭，弦虚半月弓。芳菲夕雾起，暮色满房栊。\n山亭秋色满，岩牖凉风度。疏兰尚染烟，残菊犹承露。古石衣新苔，新巢封古树。历览情无极，咫尺轮光暮。\n秦川雄帝宅，函谷壮皇居。绮殿千寻起，离宫百雉余。连薨遥接汉，飞观迥凌虚。云日隐层阙，风烟出绮疏。岩廊罢机务，崇文聊驻辇。玉匣启龙图，金绳披凤篆。韦编断仍续，缥帙舒还卷。对此乃淹留，欹案观坟典。移步出词林，停舆欣武宴。雕弓写明月，骏马疑流电。惊雁落虚弦，啼猿悲急箭。阅赏诚多美，于兹乃忘倦。鸣笳临乐馆，眺听欢芳节。急管韵朱弦，清歌凝白雪。彩凤肃来仪，玄鹤纷成列。去兹郑卫声'

# %%
data = " ".join(jieba.cut(data))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/v4/j5ng6d4d2zd2n0t825276yxm0000gn/T/jieba.cache
# Loading model cost 0.797 seconds.
# Prefix dict has been built succesfully.

# %%
data[:1000]
# Out:
# '寒随 穷律变 ， 春逐 鸟声 开 。 初风 飘带 柳 ， 晚雪间 花梅 。 碧林 青旧 竹 ， 绿 沼翠新 苔 。 芝田 初雁去 ， 绮 树巧莺来 。 \n 晚霞 聊自怡 ， 初晴 弥 可喜 。 日晃 百花 色 ， 风动 千林翠 。 池 鱼跃 不同 ， 园 鸟声 还异 。 寄言博 通者 ， 知予 物外志 。 \n 一朝 春夏 改 ， 隔夜 鸟花迁 。 阴阳 深浅 叶 ， 晓夕 重轻烟 。 哢 莺 犹响 殿 ， 横丝正 网天 。 珮 高兰 影接 ， 绶 细草纹 连 。 碧 鳞 惊 棹 侧 ， 玄燕舞 檐前 。 何必 汾阳 处 ， 始复 有 山泉 。 \n 夏律 昨留 灰 ， 秋箭 今移 晷 。 峨嵋 岫 初出 ， 洞庭 波渐 起 。 桂 白发 幽岩 ， 菊黄 开 灞 涘 。 运流 方可 叹 ， 含毫 属 微理 。 \n 寒惊 蓟门 叶 ， 秋发 小山 枝 。 松阴 背日 转 ， 竹影 避风 移 。 提壶 菊花 岸 ， 高兴 芙蓉 池 。 欲知 凉气 早 ， 巢空燕 不 窥 。 \n 爽气 浮丹 阙 ， 秋光 澹 紫宫 。 衣碎 荷 疏影 ， 花明菊点 丛 。 袍 轻低 草露 ， 盖侧 舞松风 。 散 岫 飘云叶 ， 迷路 飞烟 鸿 。 砌 冷兰 凋佩 ， 闺寒树 陨桐 。 别鹤栖琴 里 ， 离 猿啼 峡中 。 落野 飞星 箭 ， 弦 虚 半月 弓 。 芳菲 夕雾 起 ， 暮色 满房 栊 。 \n 山亭 秋色 满 ， 岩牖 凉风 度 。 疏兰 尚染烟 ， 残菊 犹承露 。 古石衣 新 苔 ， 新巢 封 古树 。 历览 情 无极 ， 咫尺 轮光 暮 。 \n 秦川 雄帝 宅 ， 函谷壮 皇居 。 绮 殿 千寻起 ， 离宫 百雉 余 。 连 薨 遥 接汉 ， 飞观 迥凌虚 。 云日 隐层 阙 ， 风烟 出 绮 疏 。 岩廊 罢 机务 ， 崇文 聊 驻 辇 。 玉匣 启龙图 ， 金绳 披凤 篆 。 韦编断 仍续 ， 缥帙舒 还 卷 。 对此 乃 淹留 ， 欹 案观 坟典 。 移步 出 词林 ， 停 舆欣 武宴 。 雕弓 写明 月 ， 骏马 疑 流电 。 惊雁落 虚 弦 ， 啼猿 悲急 箭 。 阅赏 诚多美 ， 于兹 乃 忘倦 。 鸣笳 临乐馆 ， 眺听 欢芳节 。 急管韵 朱弦 ， 清歌 凝 白雪 。 彩凤肃 来仪 ， 玄鹤纷 成列 。 去兹 郑卫声 ， 雅音 方可 悦 。 芳辰 追 逸趣'

# %%
wordcloud = WordCloud(max_font_size=50, max_words=100,
                   background_color="white", 
                   font_path="/Users/hkmac/Desktop/simsun.ttf").generate(data)

# %%
plt.rcParams['savefig.dpi'] = 300
plt.figure(figsize = (8,4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.savefig("poemcloud.png")
plt.show()

# %%
corpus = data.split("\n")
corpus[:5]
# Out:
# ['寒随 穷律变 ， 春逐 鸟声 开 。 初风 飘带 柳 ， 晚雪间 花梅 。 碧林 青旧 竹 ， 绿 沼翠新 苔 。 芝田 初雁去 ， 绮 树巧莺来 。 ',
#  ' 晚霞 聊自怡 ， 初晴 弥 可喜 。 日晃 百花 色 ， 风动 千林翠 。 池 鱼跃 不同 ， 园 鸟声 还异 。 寄言博 通者 ， 知予 物外志 。 ',
#  ' 一朝 春夏 改 ， 隔夜 鸟花迁 。 阴阳 深浅 叶 ， 晓夕 重轻烟 。 哢 莺 犹响 殿 ， 横丝正 网天 。 珮 高兰 影接 ， 绶 细草纹 连 。 碧 鳞 惊 棹 侧 ， 玄燕舞 檐前 。 何必 汾阳 处 ， 始复 有 山泉 。 ',
#  ' 夏律 昨留 灰 ， 秋箭 今移 晷 。 峨嵋 岫 初出 ， 洞庭 波渐 起 。 桂 白发 幽岩 ， 菊黄 开 灞 涘 。 运流 方可 叹 ， 含毫 属 微理 。 ',
#  ' 寒惊 蓟门 叶 ， 秋发 小山 枝 。 松阴 背日 转 ， 竹影 避风 移 。 提壶 菊花 岸 ， 高兴 芙蓉 池 。 欲知 凉气 早 ， 巢空燕 不 窥 。 ']

# %%
length = []
for line in corpus:
    length.append(len(line))

# %%
pd.Series(length).describe()
# Out:
# count    43031.000000
# mean       116.884200
# std        156.704648
# min          0.000000
# 25%         61.000000
# 50%         81.000000
# 75%        109.000000
# max       8154.000000
# dtype: float64

# %%
corpus_new = []
for i in corpus:
    if '_' in i or '(' in i or '（' in i or '《' in i or '[' in i:
        continue
    if len(i) < 61 or len(i) > 200:
        continue
    else:
        corpus_new.append(i)

# %%
length_new = []
for line in corpus_new:
    length_new.append(len(line))

# %%
pd.Series(length_new).describe()
# Out:
# count    27897.000000
# mean       101.577804
# std         29.655401
# min         61.000000
# 25%         80.000000
# 50%        100.000000
# 75%        108.000000
# max        200.000000
# dtype: float64

# %%
# how many words to select
vocab_size = 10000
embedding_dim = 20
max_length = 200
trunc_type='post'

# %%
tokenizer = Tokenizer(num_words = vocab_size)
tokenizer.fit_on_texts(corpus_new)
total_words = len(tokenizer.word_index)

print(total_words)
# Out:
# 199188

# %%
tokenizer.word_index
# Out:
# {'，': 1,
#  '。': 2,
#  '在': 3,
#  '月': 4,
#  '去': 5,
#  '不': 6,
#  '有': 7,
#  '与': 8,
#  '还': 9,
#  '谁': 10,
#  '是': 11,
#  '人': 12,
#  '无': 13,
#  '为': 14,
#  '上': 15,
#  '将': 16,
#  '来': 17,
#  '日': 18,
#  '更': 19,
#  '中': 20,
#  '归': 21,
#  '我': 22,
#  '多': 23,
#  '欲': 24,
#  '亦': 25,
#  '年': 26,
#  '向': 27,
#  '见': 28,
#  '已': 29,
#  '得': 30,
#  '时': 31,
#  '尽': 32,
#  '下': 33,
#  '新': 34,
#  '远': 35,
#  '又': 36,
#  '到': 37,
#  '道': 38,
#  '春': 39,
#  '看': 40,
#  '从': 41,
#  '和': 42,
#  '一': 43,
#  '何处': 44,
#  '却': 45,
#  '好': 46,
#  '未': 47,
#  '深': 48,
#  '老': 49,
#  '如': 50,
#  '出': 51,
#  '万里': 52,
#  '馀': 53,
#  '路': 54,
#  '对': 55,
#  '后': 56,
#  '客': 57,
#  '愁': 58,
#  '起': 59,
#  '酒': 60,
#  '事': 61,
#  '过': 62,
#  '里': 63,
#  '空': 64,
#  '长': 65,
#  '皆': 66,
#  '处': 67,
#  '心': 68,
#  '开': 69,
#  '清': 70,
#  '坐': 71,
#  '才': 72,
#  '白云': 73,
#  '飞': 74,
#  '不知': 75,
#  '曾': 76,
#  '听': 77,
#  '地': 78,
#  '千里': 79,
#  '暮': 80,
#  '回': 81,
#  '自': 82,
#  '岂': 83,
#  '同': 84,
#  '雨': 85,
#  '别': 86,
#  '今日': 87,
#  '望': 88,
#  '秋': 89,
#  '难': 90,
#  '风': 91,
#  '能': 92,
#  '花': 93,
#  '醉': 94,
#  '水': 95,
#  '梦': 96,
#  '云': 97,
#  '高': 98,
#  '满': 99,
#  '春风': 100,
#  '问': 101,
#  '兮': 102,
#  '寒': 103,
#  '且': 104,
#  '生': 105,
#  '入': 106,
#  '初': 107,
#  '闲': 108,
#  '他': 109,
#  '应': 110,
#  '落': 111,
#  '前': 112,
#  '若': 113,
#  '此': 114,
#  '吾': 115,
#  '共': 116,
#  '故人': 117,
#  '雪': 118,
#  '恨': 119,
#  '久': 120,
#  '便': 121,
#  '山': 122,
#  '寄': 123,
#  '晚': 124,
#  '不可': 125,
#  '外': 126,
#  '迟': 127,
#  '吹': 128,
#  '行': 129,
#  '惆怅': 130,
#  '犹': 131,
#  '棹': 132,
#  '秋风': 133,
#  '旧': 134,
#  '说': 135,
#  '□': 136,
#  '鸟': 137,
#  '明月': 138,
#  '知': 139,
#  '不见': 140,
#  '岁': 141,
#  '诗': 142,
#  '只': 143,
#  '斜': 144,
#  '相思': 145,
#  '近': 146,
#  '人间': 147,
#  '郡': 148,
#  '惊': 149,
#  '无人': 150,
#  '似': 151,
#  '之': 152,
#  '树': 153,
#  '重': 154,
#  '寻': 155,
#  '隔': 156,
#  '悠悠': 157,
#  '稀': 158,
#  '都': 159,
#  '天': 160,
#  '白': 161,
#  '至': 162,
#  '君': 163,
#  '红': 164,
#  '青山': 165,
#  '闻': 166,
#  '笑': 167,
#  '连': 168,
#  '间': 169,
#  '霜': 170,
#  '如何': 171,
#  '夜': 172,
#  '今': 173,
#  '待': 174,
#  '罢': 175,
#  '绿': 176,
#  '相逢': 177,
#  '随': 178,
#  '垂': 179,
#  '香': 180,
#  '声': 181,
#  '非': 182,
#  '草': 183,
#  '即': 184,
#  '何人': 185,
#  '碧': 186,
#  '意': 187,
#  '但': 188,
#  '烟': 189,
#  '分': 190,
#  '正': 191,
#  '仍': 192,
#  '书': 193,
#  '门': 194,
#  '游': 195,
#  '少': 196,
#  '芳草': 197,
#  '倚': 198,
#  '被': 199,
#  '回首': 200,
#  '把': 201,
#  '住': 202,
#  '不得': 203,
#  '疏': 204,
#  '轻': 205,
#  '寂寞': 206,
#  '夕阳': 207,
#  '早': 208,
#  '阙': 209,
#  '身': 210,
#  '僧': 211,
#  '平生': 212,
#  '阴': 213,
#  '送': 214,
#  '白日': 215,
#  '暖': 216,
#  '长安': 217,
#  '吟': 218,
#  '寺': 219,
#  '嗟': 220,
#  '色': 221,
#  '使': 222,
#  '朝': 223,
#  '尘': 224,
#  '当': 225,
#  '逢': 226,
#  '催': 227,
#  '独': 228,
#  '竹': 229,
#  '落日': 230,
#  '忽': 231,
#  '悲': 232,
#  '少年': 233,
#  '发': 234,
#  '虽': 235,
#  '何事': 236,
#  '白发': 237,
#  '从此': 238,
#  '思': 239,
#  '莫': 240,
#  '就': 241,
#  '相': 242,
#  '何时': 243,
#  '流水': 244,
#  '可': 245,
#  '明': 246,
#  '遂': 247,
#  '所': 248,
#  '孤': 249,
#  '城': 250,
#  '流': 251,
#  '乡': 252,
#  '言': 253,
#  '死': 254,
#  '歌': 255,
#  '拂': 256,
#  '烟霞': 257,
#  '情': 258,
#  '忘': 259,
#  '传': 260,
#  '家': 261,
#  '何': 262,
#  '如此': 263,
#  '须': 264,
#  '相见': 265,
#  '泪': 266,
#  '并': 267,
#  '复': 268,
#  '成': 269,
#  '猿': 270,
#  '天涯': 271,
#  '急': 272,
#  '忆': 273,
#  '归去': 274,
#  '此时': 275,
#  '没': 276,
#  '妾': 277,
#  '日暮': 278,
#  '鸣': 279,
#  '迥': 280,
#  '今朝': 281,
#  '三': 282,
#  '西': 283,
#  '留': 284,
#  '也': 285,
#  '绕': 286,
#  '主人': 287,
#  '静': 288,
#  '金': 289,
#  '别离': 290,
#  '洞庭': 291,
#  '带': 292,
#  '此地': 293,
#  '十年': 294,
#  '苔': 295,
#  '转': 296,
#  '清风': 297,
#  '掩': 298,
#  '渚': 299,
#  '作': 300,
#  '傍': 301,
#  '东风': 302,
#  '小': 303,
#  '行人': 304,
#  '冷': 305,
#  '可怜': 306,
#  '两': 307,
#  '柳': 308,
#  '风吹': 309,
#  '东': 310,
#  '曲': 311,
#  '会': 312,
#  '期': 313,
#  '边': 314,
#  '爱': 315,
#  '骑': 316,
#  '参差': 317,
#  '名': 318,
#  '饮': 319,
#  '低': 320,
#  '杨柳': 321,
#  '弦': 322,
#  '残': 323,
#  '歇': 324,
#  '归来': 325,
#  '乱': 326,
#  '黄金': 327,
#  '风雨': 328,
#  '日月': 329,
#  '薄': 330,
#  '白头': 331,
#  '弄': 332,
#  '？': 333,
#  '居': 334,
#  '何如': 335,
#  '终日': 336,
#  '玉': 337,
#  '寂寥': 338,
#  '莺': 339,
#  '旆': 340,
#  '因': 341,
#  '落花': 342,
#  '天地': 343,
#  '殷勤': 344,
#  '散': 345,
#  '兼': 346,
#  '动': 347,
#  '枕': 348,
#  '鬓': 349,
#  '黄': 350,
#  '卧': 351,
#  '鹤': 352,
#  '既': 353,
#  '苍苍': 354,
#  '旌': 355,
#  '山川': 356,
#  '暝': 357,
#  '衣': 358,
#  '不如': 359,
#  '真': 360,
#  '门前': 361,
#  '萧条': 362,
#  '春色': 363,
#  '双': 364,
#  '青云': 365,
#  '绝': 366,
#  '喧': 367,
#  '者': 368,
#  '处处': 369,
#  '不是': 370,
#  '不能': 371,
#  '千年': 372,
#  '蜀': 373,
#  '翻': 374,
#  '宿': 375,
#  '簟': 376,
#  '何必': 377,
#  '偏': 378,
#  '休': 379,
#  '仙': 380,
#  '江南': 381,
#  '青': 382,
#  '微': 383,
#  '鱼': 384,
#  '唯有': 385,
#  '无限': 386,
#  '浮云': 387,
#  '筵': 388,
#  '绣': 389,
#  '不堪': 390,
#  '萧萧': 391,
#  '春草': 392,
#  '将军': 393,
#  '天子': 394,
#  '谁知': 395,
#  '枝': 396,
#  '鸾': 397,
#  '蝉': 398,
#  '砌': 399,
#  '断': 400,
#  '凭': 401,
#  '苦': 402,
#  '通': 403,
#  '悬': 404,
#  '故乡': 405,
#  '舟': 406,
#  '啼': 407,
#  '马': 408,
#  '讵': 409,
#  '穷': 410,
#  '自有': 411,
#  '飘': 412,
#  '当时': 413,
#  '乘': 414,
#  '头': 415,
#  '几时': 416,
#  '澹': 417,
#  '由': 418,
#  '山中': 419,
#  '晴': 420,
#  '合': 421,
#  '乍': 422,
#  '南山': 423,
#  '赊': 424,
#  '天下': 425,
#  '暗': 426,
#  '洛阳': 427,
#  '船': 428,
#  '芙蓉': 429,
#  '离': 430,
#  '再': 431,
#  '草木': 432,
#  '半': 433,
#  '横': 434,
#  '剑': 435,
#  '石': 436,
#  '虚': 437,
#  '幽': 438,
#  '桃李': 439,
#  '子': 440,
#  '纷纷': 441,
#  '天上': 442,
#  '倾': 443,
#  '归路': 444,
#  '不同': 445,
#  '楼': 446,
#  '辇': 447,
#  '遥': 448,
#  '杳': 449,
#  '三年': 450,
#  '大': 451,
#  '了': 452,
#  '尚': 453,
#  '紫': 454,
#  '俱': 455,
#  '穿': 456,
#  '风尘': 457,
#  '亲': 458,
#  '欹': 459,
#  '绮': 460,
#  '古': 461,
#  '风流': 462,
#  '陪': 463,
#  '樽': 464,
#  '南': 465,
#  '浅': 466,
#  '想': 467,
#  '山水': 468,
#  '湿': 469,
#  '故园': 470,
#  '沈': 471,
#  '几': 472,
#  '分明': 473,
#  '眠': 474,
#  '溪': 475,
#  '楼台': 476,
#  '如今': 477,
#  '知音': 478,
#  '依依': 479,
#  '尘埃': 480,
#  '沧海': 481,
#  '有时': 482,
#  '抛': 483,
#  '先生': 484,
#  '君子': 485,
#  '光': 486,
#  '神仙': 487,
#  '抱': 488,
#  '笙歌': 489,
#  '一枝': 490,
#  '攀': 491,
#  '堪': 492,
#  '气': 493,
#  '咏': 494,
#  '樵': 495,
#  '挂': 496,
#  '台': 497,
#  '照': 498,
#  '江': 499,
#  '竟': 500,
#  '一声': 501,
#  '鸳鸯': 502,
#  '潇湘': 503,
#  '属': 504,
#  '含': 505,
#  '早晚': 506,
#  '晓': 507,
#  '贫': 508,
#  '移': 509,
#  '隐': 510,
#  '露': 511,
#  '迎': 512,
#  '日日': 513,
#  '谁家': 514,
#  '松': 515,
#  '萋': 516,
#  '雁': 517,
#  '离别': 518,
#  '孤舟': 519,
#  '不觉': 520,
#  '频': 521,
#  '齐': 522,
#  '扁舟': 523,
#  '文章': 524,
#  '车马': 525,
#  '恩': 526,
#  '君王': 527,
#  '语': 528,
#  '明日': 529,
#  '先': 530,
#  '茫茫': 531,
#  '殿': 532,
#  '卷': 533,
#  '林': 534,
#  '及': 535,
#  '明朝': 536,
#  '依': 537,
#  '浓': 538,
#  '江山': 539,
#  '喜': 540,
#  '那': 541,
#  '出门': 542,
#  '著': 543,
#  '桃花': 544,
#  '裴回': 545,
#  '辞': 546,
#  '驻': 547,
#  '贵': 548,
#  '花落': 549,
#  '愿': 550,
#  '拜': 551,
#  '谒': 552,
#  '江上': 553,
#  '信': 554,
#  '凤凰': 555,
#  '昨日': 556,
#  '阑': 557,
#  '寂寂': 558,
#  '最': 559,
#  '忧': 560,
#  '旌旗': 561,
#  '浮': 562,
#  '哭': 563,
#  '东西': 564,
#  '足': 565,
#  '至今': 566,
#  '诏': 567,
#  '亭': 568,
#  '慵': 569,
#  '鳞': 570,
#  '山色': 571,
#  '不敢': 572,
#  '白首': 573,
#  '睡': 574,
#  '叶': 575,
#  '唯': 576,
#  '话': 577,
#  '秋色': 578,
#  '平': 579,
#  '秦': 580,
#  '帐': 581,
#  '宽': 582,
#  '女': 583,
#  '临': 584,
#  '涧': 585,
#  '无穷': 586,
#  '风景': 587,
#  '高楼': 588,
#  '携': 589,
#  '五': 590,
#  '歌舞': 591,
#  '往来': 592,
#  '翠': 593,
#  '千载': 594,
#  '于': 595,
#  '鸿': 596,
#  '识': 597,
#  '空山': 598,
#  '夕': 599,
#  '携手': 600,
#  '陈': 601,
#  '海上': 602,
#  '曙': 603,
#  '不成': 604,
#  '西风': 605,
#  '干': 606,
#  '霁': 607,
#  '使君': 608,
#  '知己': 609,
#  '新诗': 610,
#  '江湖': 611,
#  '接': 612,
#  '翠微': 613,
#  '秋水': 614,
#  '凉': 615,
#  '昨夜': 616,
#  '沾': 617,
#  '群': 618,
#  '牵': 619,
#  '嫌': 620,
#  '故国': 621,
#  '何日': 622,
#  '凉风': 623,
#  '捧': 624,
#  '每': 625,
#  '檐': 626,
#  '何年': 627,
#  '衣裳': 628,
#  '迷': 629,
#  '古人': 630,
#  '那堪': 631,
#  '百年': 632,
#  '邻': 633,
#  '登临': 634,
#  '四海': 635,
#  '邑': 636,
#  '画': 637,
#  '蹉跎': 638,
#  '东南': 639,
#  '青春': 640,
#  '谢': 641,
#  '尽日': 642,
#  '光辉': 643,
#  '徒': 644,
#  '占': 645,
#  '惜': 646,
#  '草堂': 647,
#  '勿': 648,
#  '借问': 649,
#  '杯': 650,
#  '漠漠': 651,
#  '钱': 652,
#  '管弦': 653,
#  '比': 654,
#  '郎': 655,
#  '才子': 656,
#  '内': 657,
#  '乐': 658,
#  '岁月': 659,
#  '关山': 660,
#  '而': 661,
#  '水流': 662,
#  '饶': 663,
#  '何以': 664,
#  '或': 665,
#  '楼上': 666,
#  '迢迢': 667,
#  '伴': 668,
#  '叹': 669,
#  '方': 670,
#  '越': 671,
#  '龙': 672,
#  '从来': 673,
#  '各': 674,
#  '不及': 675,
#  '生涯': 676,
#  '远山': 677,
#  '烟波': 678,
#  '云山': 679,
#  '窥': 680,
#  '遍': 681,
#  '送君': 682,
#  '是非': 683,
#  '岸': 684,
#  '度': 685,
#  '变': 686,
#  '赏': 687,
#  '一片': 688,
#  '无心': 689,
#  '消息': 690,
#  '舞': 691,
#  '雨露': 692,
#  '南国': 693,
#  '北': 694,
#  '落叶': 695,
#  '王孙': 696,
#  '逍遥': 697,
#  '功': 698,
#  '风光': 699,
#  '槎': 700,
#  '侵': 701,
#  '门外': 702,
#  '人家': 703,
#  '一夜': 704,
#  '怨': 705,
#  '懒': 706,
#  '凝': 707,
#  '经': 708,
#  '道路': 709,
#  '伤': 710,
#  '云雨': 711,
#  '碧云': 712,
#  '字': 713,
#  '终': 714,
#  '鸡': 715,
#  '半夜': 716,
#  '病': 717,
#  '人生': 718,
#  '怅望': 719,
#  '夜深': 720,
#  '唱': 721,
#  '黍': 722,
#  '宫': 723,
#  '青青': 724,
#  '走': 725,
#  '世间': 726,
#  '守': 727,
#  '影': 728,
#  '山河': 729,
#  '矣': 730,
#  '佳人': 731,
#  '不胜': 732,
#  '闻道': 733,
#  '临水': 734,
#  '锦': 735,
#  '去年': 736,
#  '绛': 737,
#  '一曲': 738,
#  '时节': 739,
#  '焚香': 740,
#  '极': 741,
#  '自然': 742,
#  '林下': 743,
#  '破': 744,
#  '淹留': 745,
#  '乃': 746,
#  '湲': 747,
#  '万古': 748,
#  '帘': 749,
#  '杖': 750,
#  '栖': 751,
#  '桡': 752,
#  '一身': 753,
#  '栽': 754,
#  '畔': 755,
#  '无处': 756,
#  '本': 757,
#  '赠': 758,
#  '火': 759,
#  '江边': 760,
#  '题诗': 761,
#  '芳菲': 762,
#  '九': 763,
#  '白雪': 764,
#  '写': 765,
#  '用': 766,
#  '冥': 767,
#  '翁': 768,
#  '沧浪': 769,
#  '楚': 770,
#  '收': 771,
#  '天台': 772,
#  '此去': 773,
#  '的': 774,
#  '一年': 775,
#  '背': 776,
#  '泥': 777,
#  '知君': 778,
#  '故': 779,
#  '折': 780,
#  '宅': 781,
#  '指': 782,
#  '枯': 783,
#  '零落': 784,
#  '东山': 785,
#  '任': 786,
#  '几年': 787,
#  '阁': 788,
#  '扫': 789,
#  '神': 790,
#  '独有': 791,
#  '兴': 792,
#  '追': 793,
#  '一杯': 794,
#  '吟诗': 795,
#  '灞': 796,
#  '聊': 797,
#  '敢': 798,
#  '江海': 799,
#  '山下': 800,
#  '自古': 801,
#  '年少': 802,
#  '此生': 803,
#  '谿': 804,
#  '几处': 805,
#  '兹': 806,
#  '圆': 807,
#  '摇': 808,
#  '千古': 809,
#  '异': 810,
#  '草色': 811,
#  '阔': 812,
#  '春日': 813,
#  '归心': 814,
#  '千峰': 815,
#  '暂': 816,
#  '宴': 817,
#  '白马': 818,
#  '要': 819,
#  '斋': 820,
#  '马蹄': 821,
#  '明主': 822,
#  '残阳': 823,
#  '郭': 824,
#  '岫': 825,
#  '安': 826,
#  '无事': 827,
#  '赴': 828,
#  '忝': 829,
#  '藏': 830,
#  '一日': 831,
#  '登': 832,
#  '引': 833,
#  '几日': 834,
#  '寒食': 835,
#  '念': 836,
#  '赋': 837,
#  '余': 838,
#  '经过': 839,
#  '相望': 840,
#  '春来': 841,
#  '渐': 842,
#  '相识': 843,
#  '赐': 844,
#  '春光': 845,
#  '未能': 846,
#  '田': 847,
#  '峰': 848,
#  '二月': 849,
#  '一生': 850,
#  '相随': 851,
#  '伤心': 852,
#  '买': 853,
#  '劳': 854,
#  '相亲': 855,
#  '江城': 856,
#  '野人': 857,
#  '常': 858,
#  '残月': 859,
#  '泉': 860,
#  '朱': 861,
#  '泣': 862,
#  '御': 863,
#  '池上': 864,
#  '眼前': 865,
#  '甚': 866,
#  '摇落': 867,
#  '无情': 868,
#  '一朝': 869,
#  '禅': 870,
#  '造化': 871,
#  '车': 872,
#  '其': 873,
#  '乾坤': 874,
#  '来往': 875,
#  '今年': 876,
#  '万': 877,
#  '披': 878,
#  '鼙': 879,
#  '千万': 880,
#  '憔悴': 881,
#  '人心': 882,
#  '羞': 883,
#  '达': 884,
#  '定': 885,
#  '觅': 886,
#  '秋月': 887,
#  '自怜': 888,
#  '时时': 889,
#  '杯酒': 890,
#  '蛩': 891,
#  '叫': 892,
#  '曛': 893,
#  '人事': 894,
#  '衔': 895,
#  '何曾': 896,
#  '风月': 897,
#  '泠': 898,
#  '啄': 899,
#  '公子': 900,
#  '丝': 901,
#  '日夕': 902,
#  '风烟': 903,
#  '熟': 904,
#  '官': 905,
#  '浮生': 906,
#  '簪': 907,
#  '不用': 908,
#  '颜色': 909,
#  '映': 910,
#  '游子': 911,
#  '明年': 912,
#  '佳期': 913,
#  '依旧': 914,
#  '昔': 915,
#  '屡': 916,
#  '芳': 917,
#  '姓名': 918,
#  '未知': 919,
#  '红叶': 920,
#  '登高': 921,
#  '今夜': 922,
#  '诸侯': 923,
#  '太守': 924,
#  '今来': 925,
#  '凫': 926,
#  '呈': 927,
#  '疾': 928,
#  '觞': 929,
#  '礼': 930,
#  '丞相': 931,
#  '不尽': 932,
#  '江水': 933,
#  '钩': 934,
#  '游人': 935,
#  '滴': 936,
#  '黄叶': 937,
#  '篇': 938,
#  '独立': 939,
#  '盛': 940,
#  '虏': 941,
#  '蓬莱': 942,
#  '胜': 943,
#  '登楼': 944,
#  '所思': 945,
#  '多少': 946,
#  '黑': 947,
#  '家贫': 948,
#  '波': 949,
#  '灭': 950,
#  '眇': 951,
#  '直': 952,
#  '钟': 953,
#  '断肠': 954,
#  '琴': 955,
#  '堕': 956,
#  '迢递': 957,
#  '谩': 958,
#  '几度': 959,
#  '凄凉': 960,
#  '万国': 961,
#  '灯': 962,
#  '以': 963,
#  '自知': 964,
#  '池塘': 965,
#  '鼓': 966,
#  '何须': 967,
#  '相看': 968,
#  '净': 969,
#  '裘': 970,
#  '公卿': 971,
#  '四邻': 972,
#  '卷帘': 973,
#  '徘徊': 974,
#  '论': 975,
#  '百花': 976,
#  '珮': 977,
#  '灰': 978,
#  '昔年': 979,
#  '雾': 980,
#  '称': 981,
#  '学': 982,
#  '当年': 983,
#  '波涛': 984,
#  '绮罗': 985,
#  '花枝': 986,
#  '远近': 987,
#  '可见': 988,
#  '旧游': 989,
#  '欢娱': 990,
#  '塞': 991,
#  '臣': 992,
#  '魂': 993,
#  '思归': 994,
#  '遗': 995,
#  '葭': 996,
#  '郢': 997,
#  '四时': 998,
#  '黄河': 999,
#  '报': 1000,
#  ...}

# %%
del tokenizer.word_index['，']
del tokenizer.word_index['。']

# %%
tokenizer.word_index
# Out:
# {'在': 3,
#  '月': 4,
#  '去': 5,
#  '不': 6,
#  '有': 7,
#  '与': 8,
#  '还': 9,
#  '谁': 10,
#  '是': 11,
#  '人': 12,
#  '无': 13,
#  '为': 14,
#  '上': 15,
#  '将': 16,
#  '来': 17,
#  '日': 18,
#  '更': 19,
#  '中': 20,
#  '归': 21,
#  '我': 22,
#  '多': 23,
#  '欲': 24,
#  '亦': 25,
#  '年': 26,
#  '向': 27,
#  '见': 28,
#  '已': 29,
#  '得': 30,
#  '时': 31,
#  '尽': 32,
#  '下': 33,
#  '新': 34,
#  '远': 35,
#  '又': 36,
#  '到': 37,
#  '道': 38,
#  '春': 39,
#  '看': 40,
#  '从': 41,
#  '和': 42,
#  '一': 43,
#  '何处': 44,
#  '却': 45,
#  '好': 46,
#  '未': 47,
#  '深': 48,
#  '老': 49,
#  '如': 50,
#  '出': 51,
#  '万里': 52,
#  '馀': 53,
#  '路': 54,
#  '对': 55,
#  '后': 56,
#  '客': 57,
#  '愁': 58,
#  '起': 59,
#  '酒': 60,
#  '事': 61,
#  '过': 62,
#  '里': 63,
#  '空': 64,
#  '长': 65,
#  '皆': 66,
#  '处': 67,
#  '心': 68,
#  '开': 69,
#  '清': 70,
#  '坐': 71,
#  '才': 72,
#  '白云': 73,
#  '飞': 74,
#  '不知': 75,
#  '曾': 76,
#  '听': 77,
#  '地': 78,
#  '千里': 79,
#  '暮': 80,
#  '回': 81,
#  '自': 82,
#  '岂': 83,
#  '同': 84,
#  '雨': 85,
#  '别': 86,
#  '今日': 87,
#  '望': 88,
#  '秋': 89,
#  '难': 90,
#  '风': 91,
#  '能': 92,
#  '花': 93,
#  '醉': 94,
#  '水': 95,
#  '梦': 96,
#  '云': 97,
#  '高': 98,
#  '满': 99,
#  '春风': 100,
#  '问': 101,
#  '兮': 102,
#  '寒': 103,
#  '且': 104,
#  '生': 105,
#  '入': 106,
#  '初': 107,
#  '闲': 108,
#  '他': 109,
#  '应': 110,
#  '落': 111,
#  '前': 112,
#  '若': 113,
#  '此': 114,
#  '吾': 115,
#  '共': 116,
#  '故人': 117,
#  '雪': 118,
#  '恨': 119,
#  '久': 120,
#  '便': 121,
#  '山': 122,
#  '寄': 123,
#  '晚': 124,
#  '不可': 125,
#  '外': 126,
#  '迟': 127,
#  '吹': 128,
#  '行': 129,
#  '惆怅': 130,
#  '犹': 131,
#  '棹': 132,
#  '秋风': 133,
#  '旧': 134,
#  '说': 135,
#  '□': 136,
#  '鸟': 137,
#  '明月': 138,
#  '知': 139,
#  '不见': 140,
#  '岁': 141,
#  '诗': 142,
#  '只': 143,
#  '斜': 144,
#  '相思': 145,
#  '近': 146,
#  '人间': 147,
#  '郡': 148,
#  '惊': 149,
#  '无人': 150,
#  '似': 151,
#  '之': 152,
#  '树': 153,
#  '重': 154,
#  '寻': 155,
#  '隔': 156,
#  '悠悠': 157,
#  '稀': 158,
#  '都': 159,
#  '天': 160,
#  '白': 161,
#  '至': 162,
#  '君': 163,
#  '红': 164,
#  '青山': 165,
#  '闻': 166,
#  '笑': 167,
#  '连': 168,
#  '间': 169,
#  '霜': 170,
#  '如何': 171,
#  '夜': 172,
#  '今': 173,
#  '待': 174,
#  '罢': 175,
#  '绿': 176,
#  '相逢': 177,
#  '随': 178,
#  '垂': 179,
#  '香': 180,
#  '声': 181,
#  '非': 182,
#  '草': 183,
#  '即': 184,
#  '何人': 185,
#  '碧': 186,
#  '意': 187,
#  '但': 188,
#  '烟': 189,
#  '分': 190,
#  '正': 191,
#  '仍': 192,
#  '书': 193,
#  '门': 194,
#  '游': 195,
#  '少': 196,
#  '芳草': 197,
#  '倚': 198,
#  '被': 199,
#  '回首': 200,
#  '把': 201,
#  '住': 202,
#  '不得': 203,
#  '疏': 204,
#  '轻': 205,
#  '寂寞': 206,
#  '夕阳': 207,
#  '早': 208,
#  '阙': 209,
#  '身': 210,
#  '僧': 211,
#  '平生': 212,
#  '阴': 213,
#  '送': 214,
#  '白日': 215,
#  '暖': 216,
#  '长安': 217,
#  '吟': 218,
#  '寺': 219,
#  '嗟': 220,
#  '色': 221,
#  '使': 222,
#  '朝': 223,
#  '尘': 224,
#  '当': 225,
#  '逢': 226,
#  '催': 227,
#  '独': 228,
#  '竹': 229,
#  '落日': 230,
#  '忽': 231,
#  '悲': 232,
#  '少年': 233,
#  '发': 234,
#  '虽': 235,
#  '何事': 236,
#  '白发': 237,
#  '从此': 238,
#  '思': 239,
#  '莫': 240,
#  '就': 241,
#  '相': 242,
#  '何时': 243,
#  '流水': 244,
#  '可': 245,
#  '明': 246,
#  '遂': 247,
#  '所': 248,
#  '孤': 249,
#  '城': 250,
#  '流': 251,
#  '乡': 252,
#  '言': 253,
#  '死': 254,
#  '歌': 255,
#  '拂': 256,
#  '烟霞': 257,
#  '情': 258,
#  '忘': 259,
#  '传': 260,
#  '家': 261,
#  '何': 262,
#  '如此': 263,
#  '须': 264,
#  '相见': 265,
#  '泪': 266,
#  '并': 267,
#  '复': 268,
#  '成': 269,
#  '猿': 270,
#  '天涯': 271,
#  '急': 272,
#  '忆': 273,
#  '归去': 274,
#  '此时': 275,
#  '没': 276,
#  '妾': 277,
#  '日暮': 278,
#  '鸣': 279,
#  '迥': 280,
#  '今朝': 281,
#  '三': 282,
#  '西': 283,
#  '留': 284,
#  '也': 285,
#  '绕': 286,
#  '主人': 287,
#  '静': 288,
#  '金': 289,
#  '别离': 290,
#  '洞庭': 291,
#  '带': 292,
#  '此地': 293,
#  '十年': 294,
#  '苔': 295,
#  '转': 296,
#  '清风': 297,
#  '掩': 298,
#  '渚': 299,
#  '作': 300,
#  '傍': 301,
#  '东风': 302,
#  '小': 303,
#  '行人': 304,
#  '冷': 305,
#  '可怜': 306,
#  '两': 307,
#  '柳': 308,
#  '风吹': 309,
#  '东': 310,
#  '曲': 311,
#  '会': 312,
#  '期': 313,
#  '边': 314,
#  '爱': 315,
#  '骑': 316,
#  '参差': 317,
#  '名': 318,
#  '饮': 319,
#  '低': 320,
#  '杨柳': 321,
#  '弦': 322,
#  '残': 323,
#  '歇': 324,
#  '归来': 325,
#  '乱': 326,
#  '黄金': 327,
#  '风雨': 328,
#  '日月': 329,
#  '薄': 330,
#  '白头': 331,
#  '弄': 332,
#  '？': 333,
#  '居': 334,
#  '何如': 335,
#  '终日': 336,
#  '玉': 337,
#  '寂寥': 338,
#  '莺': 339,
#  '旆': 340,
#  '因': 341,
#  '落花': 342,
#  '天地': 343,
#  '殷勤': 344,
#  '散': 345,
#  '兼': 346,
#  '动': 347,
#  '枕': 348,
#  '鬓': 349,
#  '黄': 350,
#  '卧': 351,
#  '鹤': 352,
#  '既': 353,
#  '苍苍': 354,
#  '旌': 355,
#  '山川': 356,
#  '暝': 357,
#  '衣': 358,
#  '不如': 359,
#  '真': 360,
#  '门前': 361,
#  '萧条': 362,
#  '春色': 363,
#  '双': 364,
#  '青云': 365,
#  '绝': 366,
#  '喧': 367,
#  '者': 368,
#  '处处': 369,
#  '不是': 370,
#  '不能': 371,
#  '千年': 372,
#  '蜀': 373,
#  '翻': 374,
#  '宿': 375,
#  '簟': 376,
#  '何必': 377,
#  '偏': 378,
#  '休': 379,
#  '仙': 380,
#  '江南': 381,
#  '青': 382,
#  '微': 383,
#  '鱼': 384,
#  '唯有': 385,
#  '无限': 386,
#  '浮云': 387,
#  '筵': 388,
#  '绣': 389,
#  '不堪': 390,
#  '萧萧': 391,
#  '春草': 392,
#  '将军': 393,
#  '天子': 394,
#  '谁知': 395,
#  '枝': 396,
#  '鸾': 397,
#  '蝉': 398,
#  '砌': 399,
#  '断': 400,
#  '凭': 401,
#  '苦': 402,
#  '通': 403,
#  '悬': 404,
#  '故乡': 405,
#  '舟': 406,
#  '啼': 407,
#  '马': 408,
#  '讵': 409,
#  '穷': 410,
#  '自有': 411,
#  '飘': 412,
#  '当时': 413,
#  '乘': 414,
#  '头': 415,
#  '几时': 416,
#  '澹': 417,
#  '由': 418,
#  '山中': 419,
#  '晴': 420,
#  '合': 421,
#  '乍': 422,
#  '南山': 423,
#  '赊': 424,
#  '天下': 425,
#  '暗': 426,
#  '洛阳': 427,
#  '船': 428,
#  '芙蓉': 429,
#  '离': 430,
#  '再': 431,
#  '草木': 432,
#  '半': 433,
#  '横': 434,
#  '剑': 435,
#  '石': 436,
#  '虚': 437,
#  '幽': 438,
#  '桃李': 439,
#  '子': 440,
#  '纷纷': 441,
#  '天上': 442,
#  '倾': 443,
#  '归路': 444,
#  '不同': 445,
#  '楼': 446,
#  '辇': 447,
#  '遥': 448,
#  '杳': 449,
#  '三年': 450,
#  '大': 451,
#  '了': 452,
#  '尚': 453,
#  '紫': 454,
#  '俱': 455,
#  '穿': 456,
#  '风尘': 457,
#  '亲': 458,
#  '欹': 459,
#  '绮': 460,
#  '古': 461,
#  '风流': 462,
#  '陪': 463,
#  '樽': 464,
#  '南': 465,
#  '浅': 466,
#  '想': 467,
#  '山水': 468,
#  '湿': 469,
#  '故园': 470,
#  '沈': 471,
#  '几': 472,
#  '分明': 473,
#  '眠': 474,
#  '溪': 475,
#  '楼台': 476,
#  '如今': 477,
#  '知音': 478,
#  '依依': 479,
#  '尘埃': 480,
#  '沧海': 481,
#  '有时': 482,
#  '抛': 483,
#  '先生': 484,
#  '君子': 485,
#  '光': 486,
#  '神仙': 487,
#  '抱': 488,
#  '笙歌': 489,
#  '一枝': 490,
#  '攀': 491,
#  '堪': 492,
#  '气': 493,
#  '咏': 494,
#  '樵': 495,
#  '挂': 496,
#  '台': 497,
#  '照': 498,
#  '江': 499,
#  '竟': 500,
#  '一声': 501,
#  '鸳鸯': 502,
#  '潇湘': 503,
#  '属': 504,
#  '含': 505,
#  '早晚': 506,
#  '晓': 507,
#  '贫': 508,
#  '移': 509,
#  '隐': 510,
#  '露': 511,
#  '迎': 512,
#  '日日': 513,
#  '谁家': 514,
#  '松': 515,
#  '萋': 516,
#  '雁': 517,
#  '离别': 518,
#  '孤舟': 519,
#  '不觉': 520,
#  '频': 521,
#  '齐': 522,
#  '扁舟': 523,
#  '文章': 524,
#  '车马': 525,
#  '恩': 526,
#  '君王': 527,
#  '语': 528,
#  '明日': 529,
#  '先': 530,
#  '茫茫': 531,
#  '殿': 532,
#  '卷': 533,
#  '林': 534,
#  '及': 535,
#  '明朝': 536,
#  '依': 537,
#  '浓': 538,
#  '江山': 539,
#  '喜': 540,
#  '那': 541,
#  '出门': 542,
#  '著': 543,
#  '桃花': 544,
#  '裴回': 545,
#  '辞': 546,
#  '驻': 547,
#  '贵': 548,
#  '花落': 549,
#  '愿': 550,
#  '拜': 551,
#  '谒': 552,
#  '江上': 553,
#  '信': 554,
#  '凤凰': 555,
#  '昨日': 556,
#  '阑': 557,
#  '寂寂': 558,
#  '最': 559,
#  '忧': 560,
#  '旌旗': 561,
#  '浮': 562,
#  '哭': 563,
#  '东西': 564,
#  '足': 565,
#  '至今': 566,
#  '诏': 567,
#  '亭': 568,
#  '慵': 569,
#  '鳞': 570,
#  '山色': 571,
#  '不敢': 572,
#  '白首': 573,
#  '睡': 574,
#  '叶': 575,
#  '唯': 576,
#  '话': 577,
#  '秋色': 578,
#  '平': 579,
#  '秦': 580,
#  '帐': 581,
#  '宽': 582,
#  '女': 583,
#  '临': 584,
#  '涧': 585,
#  '无穷': 586,
#  '风景': 587,
#  '高楼': 588,
#  '携': 589,
#  '五': 590,
#  '歌舞': 591,
#  '往来': 592,
#  '翠': 593,
#  '千载': 594,
#  '于': 595,
#  '鸿': 596,
#  '识': 597,
#  '空山': 598,
#  '夕': 599,
#  '携手': 600,
#  '陈': 601,
#  '海上': 602,
#  '曙': 603,
#  '不成': 604,
#  '西风': 605,
#  '干': 606,
#  '霁': 607,
#  '使君': 608,
#  '知己': 609,
#  '新诗': 610,
#  '江湖': 611,
#  '接': 612,
#  '翠微': 613,
#  '秋水': 614,
#  '凉': 615,
#  '昨夜': 616,
#  '沾': 617,
#  '群': 618,
#  '牵': 619,
#  '嫌': 620,
#  '故国': 621,
#  '何日': 622,
#  '凉风': 623,
#  '捧': 624,
#  '每': 625,
#  '檐': 626,
#  '何年': 627,
#  '衣裳': 628,
#  '迷': 629,
#  '古人': 630,
#  '那堪': 631,
#  '百年': 632,
#  '邻': 633,
#  '登临': 634,
#  '四海': 635,
#  '邑': 636,
#  '画': 637,
#  '蹉跎': 638,
#  '东南': 639,
#  '青春': 640,
#  '谢': 641,
#  '尽日': 642,
#  '光辉': 643,
#  '徒': 644,
#  '占': 645,
#  '惜': 646,
#  '草堂': 647,
#  '勿': 648,
#  '借问': 649,
#  '杯': 650,
#  '漠漠': 651,
#  '钱': 652,
#  '管弦': 653,
#  '比': 654,
#  '郎': 655,
#  '才子': 656,
#  '内': 657,
#  '乐': 658,
#  '岁月': 659,
#  '关山': 660,
#  '而': 661,
#  '水流': 662,
#  '饶': 663,
#  '何以': 664,
#  '或': 665,
#  '楼上': 666,
#  '迢迢': 667,
#  '伴': 668,
#  '叹': 669,
#  '方': 670,
#  '越': 671,
#  '龙': 672,
#  '从来': 673,
#  '各': 674,
#  '不及': 675,
#  '生涯': 676,
#  '远山': 677,
#  '烟波': 678,
#  '云山': 679,
#  '窥': 680,
#  '遍': 681,
#  '送君': 682,
#  '是非': 683,
#  '岸': 684,
#  '度': 685,
#  '变': 686,
#  '赏': 687,
#  '一片': 688,
#  '无心': 689,
#  '消息': 690,
#  '舞': 691,
#  '雨露': 692,
#  '南国': 693,
#  '北': 694,
#  '落叶': 695,
#  '王孙': 696,
#  '逍遥': 697,
#  '功': 698,
#  '风光': 699,
#  '槎': 700,
#  '侵': 701,
#  '门外': 702,
#  '人家': 703,
#  '一夜': 704,
#  '怨': 705,
#  '懒': 706,
#  '凝': 707,
#  '经': 708,
#  '道路': 709,
#  '伤': 710,
#  '云雨': 711,
#  '碧云': 712,
#  '字': 713,
#  '终': 714,
#  '鸡': 715,
#  '半夜': 716,
#  '病': 717,
#  '人生': 718,
#  '怅望': 719,
#  '夜深': 720,
#  '唱': 721,
#  '黍': 722,
#  '宫': 723,
#  '青青': 724,
#  '走': 725,
#  '世间': 726,
#  '守': 727,
#  '影': 728,
#  '山河': 729,
#  '矣': 730,
#  '佳人': 731,
#  '不胜': 732,
#  '闻道': 733,
#  '临水': 734,
#  '锦': 735,
#  '去年': 736,
#  '绛': 737,
#  '一曲': 738,
#  '时节': 739,
#  '焚香': 740,
#  '极': 741,
#  '自然': 742,
#  '林下': 743,
#  '破': 744,
#  '淹留': 745,
#  '乃': 746,
#  '湲': 747,
#  '万古': 748,
#  '帘': 749,
#  '杖': 750,
#  '栖': 751,
#  '桡': 752,
#  '一身': 753,
#  '栽': 754,
#  '畔': 755,
#  '无处': 756,
#  '本': 757,
#  '赠': 758,
#  '火': 759,
#  '江边': 760,
#  '题诗': 761,
#  '芳菲': 762,
#  '九': 763,
#  '白雪': 764,
#  '写': 765,
#  '用': 766,
#  '冥': 767,
#  '翁': 768,
#  '沧浪': 769,
#  '楚': 770,
#  '收': 771,
#  '天台': 772,
#  '此去': 773,
#  '的': 774,
#  '一年': 775,
#  '背': 776,
#  '泥': 777,
#  '知君': 778,
#  '故': 779,
#  '折': 780,
#  '宅': 781,
#  '指': 782,
#  '枯': 783,
#  '零落': 784,
#  '东山': 785,
#  '任': 786,
#  '几年': 787,
#  '阁': 788,
#  '扫': 789,
#  '神': 790,
#  '独有': 791,
#  '兴': 792,
#  '追': 793,
#  '一杯': 794,
#  '吟诗': 795,
#  '灞': 796,
#  '聊': 797,
#  '敢': 798,
#  '江海': 799,
#  '山下': 800,
#  '自古': 801,
#  '年少': 802,
#  '此生': 803,
#  '谿': 804,
#  '几处': 805,
#  '兹': 806,
#  '圆': 807,
#  '摇': 808,
#  '千古': 809,
#  '异': 810,
#  '草色': 811,
#  '阔': 812,
#  '春日': 813,
#  '归心': 814,
#  '千峰': 815,
#  '暂': 816,
#  '宴': 817,
#  '白马': 818,
#  '要': 819,
#  '斋': 820,
#  '马蹄': 821,
#  '明主': 822,
#  '残阳': 823,
#  '郭': 824,
#  '岫': 825,
#  '安': 826,
#  '无事': 827,
#  '赴': 828,
#  '忝': 829,
#  '藏': 830,
#  '一日': 831,
#  '登': 832,
#  '引': 833,
#  '几日': 834,
#  '寒食': 835,
#  '念': 836,
#  '赋': 837,
#  '余': 838,
#  '经过': 839,
#  '相望': 840,
#  '春来': 841,
#  '渐': 842,
#  '相识': 843,
#  '赐': 844,
#  '春光': 845,
#  '未能': 846,
#  '田': 847,
#  '峰': 848,
#  '二月': 849,
#  '一生': 850,
#  '相随': 851,
#  '伤心': 852,
#  '买': 853,
#  '劳': 854,
#  '相亲': 855,
#  '江城': 856,
#  '野人': 857,
#  '常': 858,
#  '残月': 859,
#  '泉': 860,
#  '朱': 861,
#  '泣': 862,
#  '御': 863,
#  '池上': 864,
#  '眼前': 865,
#  '甚': 866,
#  '摇落': 867,
#  '无情': 868,
#  '一朝': 869,
#  '禅': 870,
#  '造化': 871,
#  '车': 872,
#  '其': 873,
#  '乾坤': 874,
#  '来往': 875,
#  '今年': 876,
#  '万': 877,
#  '披': 878,
#  '鼙': 879,
#  '千万': 880,
#  '憔悴': 881,
#  '人心': 882,
#  '羞': 883,
#  '达': 884,
#  '定': 885,
#  '觅': 886,
#  '秋月': 887,
#  '自怜': 888,
#  '时时': 889,
#  '杯酒': 890,
#  '蛩': 891,
#  '叫': 892,
#  '曛': 893,
#  '人事': 894,
#  '衔': 895,
#  '何曾': 896,
#  '风月': 897,
#  '泠': 898,
#  '啄': 899,
#  '公子': 900,
#  '丝': 901,
#  '日夕': 902,
#  '风烟': 903,
#  '熟': 904,
#  '官': 905,
#  '浮生': 906,
#  '簪': 907,
#  '不用': 908,
#  '颜色': 909,
#  '映': 910,
#  '游子': 911,
#  '明年': 912,
#  '佳期': 913,
#  '依旧': 914,
#  '昔': 915,
#  '屡': 916,
#  '芳': 917,
#  '姓名': 918,
#  '未知': 919,
#  '红叶': 920,
#  '登高': 921,
#  '今夜': 922,
#  '诸侯': 923,
#  '太守': 924,
#  '今来': 925,
#  '凫': 926,
#  '呈': 927,
#  '疾': 928,
#  '觞': 929,
#  '礼': 930,
#  '丞相': 931,
#  '不尽': 932,
#  '江水': 933,
#  '钩': 934,
#  '游人': 935,
#  '滴': 936,
#  '黄叶': 937,
#  '篇': 938,
#  '独立': 939,
#  '盛': 940,
#  '虏': 941,
#  '蓬莱': 942,
#  '胜': 943,
#  '登楼': 944,
#  '所思': 945,
#  '多少': 946,
#  '黑': 947,
#  '家贫': 948,
#  '波': 949,
#  '灭': 950,
#  '眇': 951,
#  '直': 952,
#  '钟': 953,
#  '断肠': 954,
#  '琴': 955,
#  '堕': 956,
#  '迢递': 957,
#  '谩': 958,
#  '几度': 959,
#  '凄凉': 960,
#  '万国': 961,
#  '灯': 962,
#  '以': 963,
#  '自知': 964,
#  '池塘': 965,
#  '鼓': 966,
#  '何须': 967,
#  '相看': 968,
#  '净': 969,
#  '裘': 970,
#  '公卿': 971,
#  '四邻': 972,
#  '卷帘': 973,
#  '徘徊': 974,
#  '论': 975,
#  '百花': 976,
#  '珮': 977,
#  '灰': 978,
#  '昔年': 979,
#  '雾': 980,
#  '称': 981,
#  '学': 982,
#  '当年': 983,
#  '波涛': 984,
#  '绮罗': 985,
#  '花枝': 986,
#  '远近': 987,
#  '可见': 988,
#  '旧游': 989,
#  '欢娱': 990,
#  '塞': 991,
#  '臣': 992,
#  '魂': 993,
#  '思归': 994,
#  '遗': 995,
#  '葭': 996,
#  '郢': 997,
#  '四时': 998,
#  '黄河': 999,
#  '报': 1000,
#  '强': 1001,
#  '美': 1002,
#  ...}

# %%
input_sequences = []
for line in corpus_new:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)

# %%
input_sequences = np.array(pad_sequences(input_sequences, maxlen=max_length, padding='pre'))
# Out:
# array([[   0,    0,    0, ...,    0, 1775,   69],
#        [   0,    0,    0, ..., 1775,   69,  308],
#        [   0,    0,    0, ...,   69,  308,  229],
#        ...,
#        [   0,    0,    0, ..., 6271,  830,   32],
#        [   0,    0,    0, ...,  830,   32,  487],
#        [   0,    0,    0, ...,   32,  487, 8315]], dtype=int32)

# %%
xs, labels = input_sequences[:,:-1],input_sequences[:,-1]
ys = tf.keras.utils.to_categorical(labels, num_classes=total_words)

# %%
xs[1].shape
# Out:
# (199,)

# %%
model = Sequential()
model.add(Embedding(total_words, embedding_dim, input_length=max_length-1))
model.add(Bidirectional(LSTM(150)))
model.add(Dense(total_words, activation='softmax'))
model.summary()
# Out:
# WARNING:tensorflow:Entity <function standard_lstm at 0x124a240d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function standard_lstm at 0x124a240d0>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <function standard_lstm at 0x124a240d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function standard_lstm at 0x124a240d0>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function cudnn_lstm at 0x124a24158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function cudnn_lstm at 0x124a24158>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <function cudnn_lstm at 0x124a24158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function cudnn_lstm at 0x124a24158>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function standard_lstm at 0x124a240d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function standard_lstm at 0x124a240d0>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <function standard_lstm at 0x124a240d0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function standard_lstm at 0x124a240d0>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <function cudnn_lstm at 0x124a24158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function cudnn_lstm at 0x124a24158>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <function cudnn_lstm at 0x124a24158> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <function cudnn_lstm at 0x124a24158>: AttributeError: module 'gast' has no attribute 'Num'
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 199, 20)           3983760
# _________________________________________________________________
# bidirectional (Bidirectional (None, 300)               205200
# _________________________________________________________________
# dense (Dense)                (None, 199188)            59955588
# =================================================================
# Total params: 64,144,548
# Trainable params: 64,144,548
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = Adam(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
history = model.fit(xs, ys, epochs=1, verbose=1)
#print model.summary()
print(model)
# Out:
# Train on 875429 samples
#   5568/875429 [..............................] - ETA: 8:27:53 - loss: 10.6897 - accuracy: 0.0047
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-7f0fed912a45> in <module>
#       2 model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#       3 #earlystop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto')
# ----> 4 history = model.fit(xs, ys, epochs=1, verbose=1)
#       5 #print model.summary()
#       6 print(model)
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     662         validation_steps=validation_steps,
#     663         validation_freq=validation_freq,
# --> 664         steps_name='steps_per_epoch')
#     665
#     666   def evaluate(self,
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     381
#     382         # Get outputs.
# --> 383         batch_outs = f(ins_batch)
#     384         if not isinstance(batch_outs, list):
#     385           batch_outs = [batch_outs]
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in __call__(self, inputs)
#    3508         value = math_ops.cast(value, tensor.dtype)
#    3509       converted_inputs.append(value)
# -> 3510     outputs = self._graph_fn(*converted_inputs)
#    3511
#    3512     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#     570       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#     571           list(kwargs.keys()), list(self._arg_keywords)))
# --> 572     return self._call_flat(args)
#     573
#     574   def _filtered_call(self, args, kwargs):
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args)
#     669     # Only need to override the gradient in graph mode and when we have outputs.
#     670     if context.executing_eagerly() or not self.outputs:
# --> 671       outputs = self._inference_function.call(ctx, args)
#     672     else:
#     673       self._register_gradient()
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args)
#     443             attrs=("executor_type", executor_type,
#     444                    "config_proto", config),
# --> 445             ctx=ctx)
#     446       # Replace empty list with None
#     447       outputs = outputs or None
#
# //anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
    plt.plot(history.history[string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.show()

# %%
plot_graphs(history, 'accuracy')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-41d6f4a20f1a> in <module>
# ----> 1 plot_graphs(history, 'accuracy')
#
# NameError: name 'history' is not defined
